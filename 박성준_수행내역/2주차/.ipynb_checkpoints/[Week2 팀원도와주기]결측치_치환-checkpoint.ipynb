# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# 데이터 확인
os.listdir('data')
# Out:
# ['2020교통량통합.xlsx',
#  'holiday.csv',
#  '국가공휴일.xlsx',
#  '디지털 스킬셋 기술과제.docx',
#  '서울시_기상데이터.csv',
#  '실전db.csv']

# %%
# 데이터프레임 불러오기
weather_df = pd.read_csv("./data/서울시_기상데이터.csv", encoding="cp949")

# %%
display(weather_df.head())
# Out:
#     지점               일시   기온  강수량   풍속  습도  일조시간  적설량  지면온도  지중온도
# 0  108  2020-01-01 1:00 -5.9  NaN  1.7  40   NaN  NaN  -2.4   3.2
# 1  108  2020-01-01 2:00 -5.7  NaN  0.1  42   NaN  NaN  -2.4   3.1
# 2  108  2020-01-01 3:00 -5.6  0.0  0.0  46   NaN  NaN  -2.7   3.1
# 3  108  2020-01-01 4:00 -5.4  NaN  0.0  50   NaN  NaN  -2.5   3.0
# 4  108  2020-01-01 5:00 -5.2  NaN  0.0  55   NaN  NaN  -2.2   3.0

# %%
weather_df.isna().sum()
# Out:
# 지점         0
# 일시         0
# 기온         1
# 강수량     7701
# 풍속         0
# 습도         0
# 일조시간    3969
# 적설량     8552
# 지면온도       8
# 지중온도      12
# dtype: int64

# %%
# 강수량 결측치 치환
weather_df['강수량'].fillna(0, inplace=True) # 강수량 컬럼 결측치만 0으로 치환
display(weather_df)
# Out:
#        지점                일시    기온  강수량   풍속  습도  일조시간  적설량  지면온도  지중온도
# 0     108   2020-01-01 1:00  -5.9  0.0  1.7  40   NaN  NaN  -2.4   3.2
# 1     108   2020-01-01 2:00  -5.7  0.0  0.1  42   NaN  NaN  -2.4   3.1
# 2     108   2020-01-01 3:00  -5.6  0.0  0.0  46   NaN  NaN  -2.7   3.1
# 3     108   2020-01-01 4:00  -5.4  0.0  0.0  50   NaN  NaN  -2.5   3.0
# 4     108   2020-01-01 5:00  -5.2  0.0  0.0  55   NaN  NaN  -2.2   3.0
# ...   ...               ...   ...  ...  ...  ..   ...  ...   ...   ...
# 8755  108  2020-12-30 20:00 -11.8  0.0  4.8  54   NaN  NaN  -6.5   2.2
# 8756  108  2020-12-30 21:00 -12.4  0.0  3.2  58   NaN  NaN  -6.9   2.2
# 8757  108  2020-12-30 22:00 -12.7  0.0  2.8  56   NaN  NaN  -7.1   2.1
# 8758  108  2020-12-30 23:00 -12.9  0.0  2.2  54   NaN  NaN  -7.3   2.1
# 8759  108   2020-12-31 0:00 -12.7  0.0  3.4  52   NaN  NaN  -7.6   2.1
#
# [8760 rows x 10 columns]
