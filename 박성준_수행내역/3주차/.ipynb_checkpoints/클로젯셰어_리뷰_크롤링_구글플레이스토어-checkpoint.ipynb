# %%
# 애플 리뷰
# https://apps.apple.com/kr/app/%ED%81%B4%EB%A1%9C%EC%A0%AF%EC%85%B0%EC%96%B4-no-1-%ED%8C%A8%EC%85%98%EA%B3%B5%EC%9C%A0%ED%94%8C%EB%9E%AB%ED%8F%BC/id1436676772#see-all/reviews

# %%
# 주소 : https://www.closetshare.com/theclozet/main/index

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys # 엔터키 입력용
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import time

# %%
# 드라이버
driver = webdriver.Chrome('C:/Temp/chromedriver') # 웹드라이버 객체 생성

# 구글을 열어서 키워드 입력 후 이동
driver.get('https://play.google.com/store/apps/details?id=com.tc.closetshare&showAllReviews=true') # 구글 홈페이지 내용 렌더링
time.sleep(1)

# 모든 댓글 불러오기
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")


review_list = []

# 댓글 수집하기
for x in range(1,138) :
    review = driver.find_element_by_css_selector("#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div > main > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child("+str(x)+") > div > div.d15Mdf.bAhLNe > div.UD7Dzf > span:nth-child(1)")
    review_list.append(review.text)
    

print(review_list[:5])
# Out:
# ['우선 클로젯셰어 서비스에 대해서 굉장히 만족하고 있습니다. 마음에 드는 옷이 대여중인 경우가 더 많다는것은 아쉽지만, 사람 눈은 다 똑같으니까요..😢 앱 구현도 굉장히 잘 되는 편입니다. 속도도 빠르고 구현이 직관적이며 분류도 잘 되어있습니다. 다만 지금은 필요한 종류의 옷을 검색으로 찾을 만큼 분류가 세분화되진 않은것같아서, 아우터, 드레스, 상의, 하의보다 더 세분화된 카테고리가 있으면 더 좋을 것 같습니다.', '아이디어는 너무 괜찮으나 어플, CS 모두 엉망임 특히 고객센터 응대는 전부터 느꼈지만 메뉴얼이 없는 듯한 느낌. 현재 안드로이드 몇 기종에서 어플이 안열리는 상황이고, 이 상황이 며칠째 이어지고 있는데 공지 하나 없으며 카톡으로만 제공하는 고객센터에 문의하니 어플이 언제 재개 될 지는 모른다는 답 뿐.. 광고는 계속 오더만 오류에 대한 공지는 하나도 없고 현황도 고객센터 물어야만 알 수 있으며, 언제 해결될지는 아무도 모름ㅎㅎ 오류가 꽤 오래 계속 되고 있는데 이런 대처는 도저히 이해할 수 없음. 광고 전에 CS와 어플 개선에 대...\n전체 리뷰', '굉장히 느리고 멈추고 앱 구현이 잘 안됩니다 2년전에도 그랬는데 개선이 안됐네요 카테고리도 세분화가 필요하보이며 cs도 개선이 필요해보입니다..', '어플이 안열리네요. 내일 제 옷 수거해가는 날짜로 잡아놨는데 어떻게 진행되는지 확인도 못하게 생겼어요ㅜ 개선이 언제 될까요', '어플이 버거워서 그런지 버퍼가 되는경우가 있는데 서비스자체는 유용해서 자주 사용하고 있어요~^_^']

# %%
df = pd.DataFrame(review_list)

df
# Out:
#                                                      0
# 0    우선 클로젯셰어 서비스에 대해서 굉장히 만족하고 있습니다. 마음에 드는 옷이 대여중...
# 1    아이디어는 너무 괜찮으나 어플, CS 모두 엉망임 특히 고객센터 응대는 전부터 느꼈...
# 2    굉장히 느리고 멈추고 앱 구현이 잘 안됩니다 2년전에도 그랬는데 개선이 안됐네요 카...
# 3    어플이 안열리네요. 내일 제 옷 수거해가는 날짜로 잡아놨는데 어떻게 진행되는지 확인...
# 4    어플이 버거워서 그런지 버퍼가 되는경우가 있는데 서비스자체는 유용해서 자주 사용하고...
# ..                                                 ...
# 132                                            왜자꾸꺼지나요
# 133                                                안켜짐
# 134                                               너무느림
# 135                                             앱불편합니다
# 136                                             정말편하네요
#
# [137 rows x 1 columns]

# %%
df.columns = ["review"]
df
# Out:
#                                                 review
# 0    우선 클로젯셰어 서비스에 대해서 굉장히 만족하고 있습니다. 마음에 드는 옷이 대여중...
# 1    아이디어는 너무 괜찮으나 어플, CS 모두 엉망임 특히 고객센터 응대는 전부터 느꼈...
# 2    굉장히 느리고 멈추고 앱 구현이 잘 안됩니다 2년전에도 그랬는데 개선이 안됐네요 카...
# 3    어플이 안열리네요. 내일 제 옷 수거해가는 날짜로 잡아놨는데 어떻게 진행되는지 확인...
# 4    어플이 버거워서 그런지 버퍼가 되는경우가 있는데 서비스자체는 유용해서 자주 사용하고...
# ..                                                 ...
# 132                                            왜자꾸꺼지나요
# 133                                                안켜짐
# 134                                               너무느림
# 135                                             앱불편합니다
# 136                                             정말편하네요
#
# [137 rows x 1 columns]

# %%
# 특수문자 전처리
import re

# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    content = re.sub("[^a-zA-Z0-9ㄱ-힣]", "", text)
    
    return content

# %%
# ‘특수문자제거’ 컬럼을 생성
df['cleaning'] = df['review'].apply(lambda x: text_cleaning(x))
df.tail()
# Out:
#       review cleaning
# 132  왜자꾸꺼지나요  왜자꾸꺼지나요
# 133      안켜짐      안켜짐
# 134     너무느림     너무느림
# 135   앱불편합니다   앱불편합니다
# 136   정말편하네요   정말편하네요

# %%
# df.to_csv("./data/리뷰.csv")

# %%
df = pd.read_csv("./data/리뷰.csv")

# %%
# 명사추출을 위한 함수 정의
from konlpy.tag import Okt
from collections import Counter

# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "./data/korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]

def get_nouns(x):
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(x)
    
    # 한글자 키워드를 제거합니다.
    nouns = [noun for noun in nouns if len(noun) > 1]
    
    # 불용어를 제거합니다.
    nouns = [noun for noun in nouns if noun not in stopwords]
    
    return nouns

# %%
# ‘명사’ 컬럼에 이를 적용
df['noun'] = df['cleaning'].apply(lambda x: get_nouns(x))
df
# Out:
#      Unnamed: 0                                             review  \
# 0             0  우선 클로젯셰어 서비스에 대해서 굉장히 만족하고 있습니다. 마음에 드는 옷이 대여중...
# 1             1  아이디어는 너무 괜찮으나 어플, CS 모두 엉망임 특히 고객센터 응대는 전부터 느꼈...
# 2             2  굉장히 느리고 멈추고 앱 구현이 잘 안됩니다 2년전에도 그랬는데 개선이 안됐네요 카...
# 3             3  어플이 안열리네요. 내일 제 옷 수거해가는 날짜로 잡아놨는데 어떻게 진행되는지 확인...
# 4             4  어플이 버거워서 그런지 버퍼가 되는경우가 있는데 서비스자체는 유용해서 자주 사용하고...
# ..          ...                                                ...
# 132         132                                            왜자꾸꺼지나요
# 133         133                                                안켜짐
# 134         134                                               너무느림
# 135         135                                             앱불편합니다
# 136         136                                             정말편하네요
#
#                                               cleaning  \
# 0    우선클로젯셰어서비스에대해서굉장히만족하고있습니다마음에드는옷이대여중인경우가더많다는것은아...
# ...

# %%
check_list = []
for x in df['noun'] :
    check_list.append(x)

# %%
dataset = [['셰어', '서비스', '대해', '마음', '에드', '여중', '경우', '사람', '구현', '편입', '속도', '구현', '직관', '분류', '금은', '종류', '검색', '분류', '세분', '아우', '드레스', '하의', '세분', '카테고리'], ['아이디어', '어플', '엉망', '고객', '센터', '응대', '메뉴얼', '느낌', '현재', '안드로이드', '몇기종', '어플', '이안', '상황', '상황', '며칠', '카톡', '제공', '고객', '센터', '문의', '어플', '이언', '제재', '광고', '계속', '오류', '대한', '공지', '현황', '고객', '센터', '해결', '아무', '모름', '오류', '계속', '대처', '도저히', '이해', '광고', '어플', '개선', '전체', '리뷰'], ['구현', '개선'], ['어플', '이안', '수거', '날짜', '진행', '확인', '개선'], ['어플', '버퍼', '경우', '서비스', '자체', '자주', '사용'], ['엇네', '어플', '평소', '페이지', '어플', '그냥', '구독', '서비스'], ['어플', '이안', '대체', '해결', '어플', '그냥'], ['자꾸', '기본', '오류', '체크', '안함'], ['리지', '마찬가지'], ['앱왜뒤', '가기', '계속'], ['제발', '앱좀', '수정', '보완', '취지', '때문'], ['종료', '오류'], ['왜켜졋', '다가', '불안', '정항', '가요'], ['업데이트', '이후', '어플', '이안'], ['증상', '왜정', '가요'], ['어플', '무오'], ['어플', '이안'], ['자꾸', '해결'], ['사용', '실망', '서비스'], ['사기', '가방', '정말', '사진', '후기', '편이', '렌트', '도움', '자주', '계획'], ['어플', '계속', '테스트', '도안', '릴리'], ['서비스', '의도', '환경오염', '도막', '속도', '진짜', '컴퓨터', '추천', '동결', '제해', '버튼', '상담', '해지', '정신', '시스템', '임자', '동결', '제전', '해지', '해지', '버튼', '답변', '상담', '이야기', '해지', '그것', '종료', '처음', '지금', '주말', '해지', '가입', '해지', '사이트'], ['시스템', '정말', '오기', '상태', '점검', '프로', '정도', '정말', '사용', '환경', '가끔', '버벅거려', '이모', '감안', '공유', '옷장', '장점', '발전', '가능성', '무궁무진', '계속', '사용', '의향', '제발', '이맘', '고객', '목소리'], ['이용', '결과', '만족', '세탁', '상태', '쇼핑몰', '사면', '재고', '배송', '미리', '문해', '주문', '취소', '반품', '일이', '제품', '주문', '매일', '제품', '매일', '매일', '대여', '서비스', '배송', '제품', '관리', '도안', '조만간', '셰어', '신청', '번창'], ['비욘드', '정말', '진짜', '어플', '속도', '어플', '개선', '마음', '에드', '보고', '가기', '다시', '처음', '의미', '어플'], ['결혼식', '몇번', '입지', '한번', '렌트', '상태', '가모', '가격', '신랑', '옷사', '알더', '뿌듯', '신랑', '소매', '사이즈', '실패', '렌트', '본인', '체크', '필수', '남성', '복도', '센스', '와이프', '소리', '서비스', '제공'], ['서비스', '마인드', '빵점', '회사', '사진빨', '화면', '속지', '몇날', '며칠', '고민', '정도', '수준', '약속', '택배', '바람', '약속', '나중', '태보', '수준', '잘못', '사과', '변명', '업체', '수준', '리뷰', '보고', '결제', '걸돈'], ['셰어', '대한', '시스템', '가격', '어플', '성능', '진짜', '리뷰', '고해', '자꾸', '오류', '서열'], ['항상', '애용', '명품', '디자이너', '브랜드', '일리', '구매', '이득', '추천'], ['제발', '사이트', '속도', '몇개', '월전', '취소', '속도', '개선', '이안', '서비스', '스트레스', '그냥', '결제', '포기', '진짜', '지금', '속도', '도저히', '이용', '불가', '비즈니스', '순위', '반영', '속도', '때문', '이용', '고객', '고려', '속도', '개선', '결제', '제발', '개선'], ['사실', '상태', '청결', '가장', '걱정', '세탁', '새옷', '고민', '평소', '사기', '진짜', '추천'], ['평소', '가방', '배송', '택배', '포장', '안심', '이용', '중고', '판매', '상품', '상태', '에드', '구매'], ['계절', '사고', '이건', '생각', '환경', '위해', '시작', '예상', '고퀄', '브랜드', '스타일', '스타', '일링', '스펙트럼', '환경', '부담', '주지', '매일', '스타', '일링', '시도', '마리', '토끼', '느낌'], ['가방', '진짜', '가격', '가방', '렌트', '가방', '사려', '가격', '서비스', '계속', '쭈욱', '부탁'], ['어플', '자체', '정말', '속도', '어어', '버그', '모든', '장점', '속도', '개선', '개도'], ['스타일', '명품', '번만', '행사', '이벤트', '의상', '진짜', '어플'], ['처음', '설치', '속도', '개선', '이제', '리뷰', '고객', '소통', '서비스', '더욱', '발전'], ['플레이스토어', '최초', '버그', '도심', '대충', '건가', '생각', '완전', '경험', '처음'], ['한번', '가방', '설치', '일상생활', '파티', '스타일', '웨딩', '스타', '일등', '평소', '대여'], ['가입자', '지적', '정말', '실력', '세번', '콘텐츠', '뭐함', '써비', '엉망'], ['평상시', '대여', '계절', '반납'], ['평가', '별하나', '서비스', '자체', '은정', '말똥'], ['협찬', '리뷰', '아이디어', '자체', '운영', '의류', '한지'], ['셰어', '신청', '신청', '가방', '통과', '보상', '가격', '중고', '판매', '려고', '책정', '기분'], ['어플', '팝업', '뜰때', '오늘', '보기', '계속', '리뷰', '작성', '가끔', '사진', '첨부', '상담', '기능', '어플', '자체', '감수', '쉐어', '물건', '업데이트', '완료', '예사', '정도', '쉐어', '신청', '반려', '제품', '지금', '가까이', '무소식', '누가', '입다', '여름', '건가', '쉐어', '입장', '쉐어', '전체', '리뷰'], ['리뷰', '가방', '엉망', '보고', '걱정', '정말', '쉬폰', '실크', '소재', '반송', '박스', '반려', '박스', '달라', '요청', '이행', '개인', '요청', '사항', '대응', '생각', '부분', '이해', '반려', '포장', '상태', '시장', '산만', '이만원', '둘둘', '봉투', '반려', '사람', '시입', '수도', '누군가', '가입', '수도', '전체', '리뷰'], ['리뷰', '가요', '어플', '을사', '웃음', '관리', '무안', '가입', '기본', '구동', '자꾸', '쿠폰', '발급', '멤버십', '가입', '결제', '유도', '아주', '적극', '무심', '카테고리', '아무', '도안', '한참', '와중', '적기', '정도', '기본', '휴대폰', '전체', '리뷰'], ['이용권', '구매', '결정', '위해', '이용권', '사라', '팝업', '가로막', '안사면', '못봄', '가기', '만하', '아이템', '보고', '리스트', '최상', '위로', '광고', '팝업', '오늘', '보기', '쓰기', '화가', '도전'], ['결혼식', '한번', '사기', '부담', '가격', '가방', '대여'], ['의도', '정말', '합리', '가격', '구매', '대여', '사기', '옷등', '점도', '사용', '영상', '인지', '로딩', '한번', '계속', '공지', '클릭', '로딩', '악순환', '반복', '서사', '개선', '현재', '스트레스'], ['정액', '음달', '결제', '정액', '방법', '가기', '번만', '계속', '색상', '별로', '필터', '색상', '필터', '버튼', '실제', '전혀', '필터', '사람', '이대', '여중', '대여', '구매', '가격', '확인', '아예', '저번', '정액', '한번', '결제', '자동', '결제', '깜짝', '상담', '결제', '취소', '응답', '운영', '불친', '전체', '리뷰'], ['개월차', '유저', '모바일', '서비스', '기획', '개발', '개선', '정말', '서비스', '비즈니스모델', '자체', '서비스', '사용', '정말', '전단', '페이지', '진짜', '서비스', '기획', '센스', '의심', '기본', '앞서', '혹평', '주신', '심정', '사업', '자체', '매력', '제발', '헤비', '유저', '로서', '애정', '부정', '의견', '양해', '상품', '마케팅', '비즈니스', '전략', '전체', '리뷰'], ['입다', '의류', '컨셉', '멤버십', '구입', '이용', '횟수', '해주시', '좀더', '자주'], ['몇개', '이용', '정말', '사이즈', '몇번', '제사', '이즈', '사이즈', '잘못', '일도', '욤좋아욤'], ['가방', '옷장', '통과', '다시', '반품', '가방', '상태', '배송', '손잡이', '부분', '사이사이', '매듭', '표면', '진짜', '느낌', '애초', '직접', '수거', '봉투', '그냥', '검정', '봉투', '가방', '봉투', '박스', '가방', '생각', '부분', '중고', '가방', '전체', '리뷰'], ['메인', '페이지', '로딩', '더보', '려고', '카테고리', '페이지', '거기', '엉망', '고근'], ['검색', '검색', '한글', '영어', '대문자', '도제', '안나', '일일이', '클릭', '회원', '입시', '페북', '카톡', '로그인', '닉네임', '닉네임', '전체', '창싹', '진심'], ['관련', '개선', '요청', '디자인', '사이즈', '루즈', '사이즈', '도핏', '일수', '쉐어', '업로드', '의상', '자체', '기준', '사이즈', '혼란', '객관', '지표', '브랜드', '측정', '사이즈', '개선', '요청'], ['최악', '임옷', '검수', '기준', '객관성', '반려', '사유', '요구', '고객', '센터', '연락', '유선', '창구', '아예', '고객', '응대', '최악', '절대', '도안', '셰어', '거절', '반려', '일주일'], ['이용권', '구매', '여사', '정말', '상품', '페이지', '어번', '아무', '도안', '행해', '종료', '다시', '진짜', '거짓말', '수십', '개선', '보이'], ['인터넷', '항상', '을사', '생각', '여해', '보이', '종류', '별로', '정리', '불편', '쇼핑'], ['무어', '진짜', '게젤', '단점'], ['이미지', '초기', '페이지', '무거워', '속도', '이슈', '추천', '링크', '복사', '추천', '버그', '음소', '팅후', '상품', '상세', '보기', '문의', '담당자', '다시', '처음', '설명', '어플', '기능', '제한', '별도', '문의', '부분'], ['어플'], ['합리', '한번', '외투', '아치', '셰어', '사람', '이유', '종류', '진짜', '서고', '이용', '정도', '여러', '경후', '선택', '새창', '열기', '위시', '리스트', '경우', '카테고리', '설정', '클릭', '후뒤', '가기', '설정', '시초', '기화', '검색', '결과', '검색', '안나', '발견', '세탁', '안해', '어플', '오류', '자주', '전체', '리뷰'], ['스타일', '보기', '분류', '정말', '스타일', '관련', '가격', '편이'], ['가격', '사용자', '가능', '대여'], ['스타일', '종류', '별로', '구비', '통해', '구매', '도해', '스타', '일링', '비교', '덕분', '에페', '센스', '좀늘'], ['검수', '대기', '어가', '요안', '계절', '다지', '중고', '대체', '직원', '이기', '일이'], ['오류', '회원', '가입', '페이지', '카카오', '정도', '고경', '고문', '계속', '서비스', '기전', '제대로'], ['이제야', '진짜', '요강', '법도', '가격'], ['명품', '싼값', '직접', '얼굴', '대면', '거지', '가면'], ['아예', '홈페이지', '도안', '설치', '처음', '보이', '회원', '가입', '다시', '이용권', '구매', '해도', '고민'], ['정말', '사용', '사용', '다시', '쉐어', '메인', '초기'], ['어플', '버벅', '거리', '개선'], ['가입', '결제', '취소', '취소', '카톡', '고객', '센터', '로만', '취소', '처음'], ['별로', '대여', '고객', '서비스', '부실', '완전'], ['의류', '브랜드', '일상', '드레스', '선택'], ['패션', '도움', '관심'], ['사용자', '사이트', '삭제', '다시', '마찬가지', '댓글', '며칠', '황인모', '사용자', '설명'], ['지하철', '광고', '보구', '가입', '렌트', '상태', '구세', '반납', '택배', '무료', '인건비', '셰어', '대여', '적립금', '매일', '시스템', '승승장구'], ['환불', '프로', '쿠폰', '선택', '할인', '결제', '의도', '에러', '이메일', '환불'], ['갑자기', '마케팅', '의안', '팝업', '계속'], ['처음', '사용', '려고', '어플', '시작'], ['가입', '아이디', '로그', '존재', '아이디', '대체'], ['런가'], ['업데이트', '소셜', '로그인', '기능', '아예', '계속', '피드백'], ['생각', '브렌', '외국', '기준', '지불', '요전', '선택'], ['어플', '자꾸'], ['이용', '가격', '부담'], ['해도', '해결'], ['도대체', '자꾸', '중지', '그대로', '짜증'], ['게로', '인하', '매장', '오마이갓'], ['인스타', '통해', '설치', '가입', '접속', '이안'], ['투자', '별로', '서비스'], ['어플', '사용', '지게', '려고'], ['무료', '개설', '사이트', '겐안'], ['페이지'], ['어플', '며칠'], ['자체'], ['화면', '아예', '안보', '여요'], ['알림', '설정', '다시', '알림', '이오', '확인', '알림', '설정'], ['아이디어', '어플'], ['포인트', '적립', '나중'], ['왜케옷', '사진', '가요'], ['대여', '어플'], ['제발', '속도', '개선', '서비스'], ['로그인'], ['예전'], ['브랜드', '여자', '카파', '마하', '그리드', '브랜드'], ['이제'], ['옷장', '이슬'], ['관리'], ['진짜', '고객', '센터', '번호', '선택', '잘못'], ['업데이트', '이후', '이안'], ['속도', '부모님', '안부', '함암'], ['결혼식', '진짜', '최고', '무조'], ['회원', '가입', '정보', '불편', '메세지', '달랑'], ['지금', '어플', '사이트', '접속'], ['어플'], ['남자친구', '다운', '마르지', '엘라', '지방시', '구찌', '몬트', '마틀', '스몰'], ['남자'], ['탈퇴', '방법'], ['전용', '플랫폼'], ['회원', '가입'], ['어플'], ['진짜'], ['자꾸'], ['정말']]

# %%
# apriori에 필요한 모듈 설치 -> pandas와 mlxtend 미리 설치해야 함
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# 데이터셋을 원핫인코딩처럼 트랜스포밍해주기!
te = TransactionEncoder()
te_result = te.fit(dataset).transform(dataset)


# 트랜스포밍된 결과를 데이터프레임으로 형성
# 컬럼명이 키워드 / 각 row마다 포함된 키워드에 True를 반환
df = pd.DataFrame(te_result, columns=te.columns_)


# 지지도를 0.1로 낮춰서 apriori 실행
keywordset = apriori(df, min_support=0.1, use_colnames=True)
display(keywordset)


# support = A와 B가 동시에 일어난 확률 / 전체 횟수
# confidence = A와 B가 동시에 일어난 확률 / A가 일어난 횟수
# lift = A와 B가 동시에 일어난 확률 / A와 B가 독립일 확률
# Out:
#     support itemsets
# 0  0.100775     (개선)
# 1  0.131783    (서비스)
# 2  0.217054     (어플)
# 3  0.100775     (정말)
# 4  0.124031     (진짜)
