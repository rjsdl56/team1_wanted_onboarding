# %%
import pandas as pd 
import numpy as np 
#시각화
import matplotlib.pyplot as plt
import seaborn as sns
#경고무시
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

# plt.rcParams['font.family'] = 'AppleGothic' # 맥(Mac) 사용자
plt.rcParams['font.family'] = 'Malgun Gothic'  # (Windows 용) 한글 출력을 위한 글꼴 설정
# plt.rcParams['axes.unicode_minus'] = False    # 문자 - (마이너스) 정상 출력을 위한 코드

# %%
df_ori = pd.read_csv('./data/팀_basline_csv.csv', encoding='utf-8')

# %%
df=df_ori.copy()
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1461   Yves Saint Laurent                 logo point clutch bag pink
# 1462                Prada                        saffiano lux M gray
# 1463             Burberry                basic pattern sweater beige
# 1464               Chanel        graphics pattern sweat-shirts white
# 1465             Burberry                  classic trench coat beige
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 0      a161237  2019-12-06  2021-01-15  7days       BA      Y  금요일       주중
# 1     a1140859  2021-01-02  2021-01-15  4days        O      N  금요일       주중
# 2     a1140859  2021-01-02  2021-01-15  4days        B      N  금요일       주중
# 3     a1140859  2021-01-02  2021-01-15  4days        T      N  금요일       주중
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y  금요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1461   a119721  2019-04-10  2021-03-01  7days       BA      Y  공휴일       휴일
# 1462  a1146069  2021-02-11  2021-03-01  7days       BA      Y  공휴일       휴일
# 1463  a1147848  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1464  a1147788  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1465   a190054  2020-03-24  2021-03-01  4days        O      Y  공휴일       휴일
#
#       month  How_long
# 0         1       406
# 1         1        13
# 2         1        13
# 3         1        13
# 4         1        14
# ...     ...       ...
# 1461      3       691
# 1462      3        18
# 1463      3         1
# 1464      3         1
# 1465      3       342
#
# [1466 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1466 entries, 0 to 1465
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   brandnm     1466 non-null   object
#  1   goodsnm     1466 non-null   object
#  2   USER        1466 non-null   object
#  3   reg_date    1466 non-null   object
#  4   order_date  1466 non-null   object
#  5   p_type      1466 non-null   object
#  6   sub_type    1466 non-null   object
#  7   app_yn      1466 non-null   object
#  8   days        1466 non-null   object
#  9   day_type    1466 non-null   object
#  10  month       1466 non-null   int64
#  11  How_long    1466 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 137.6+ KB

# %% [markdown]
# >**(1).brandnm: 아이템의 브랜드 이름 컬럼 : 범주형 <br>
# (2).goodsnm : 아이템의 특성을 담은 이름 컬럼 : 범주형 <br>
# (3). USER : 사용자 ID 컬럼 : 범주형 <br>
# (4). reg_date : 사용자 가입일 컬럼 : 날짜형 <br>
# (5). order_date : 아이템 주문일 컬럼 : 날짜형<br>
# (6). p_type : 주문 상품권 종류 5일 7일 : 범주형<br>
# (7). sub_type : 주문 아이템 카테고리 : 범주형 <br>
# (8). add_yn : 사용자의 어플리케이션 사용 여부 : 범주형**

# %% [markdown]
# # Retention, Revenue

# %% [markdown]
# ## 사용자의 재방문률을 높이고 구매를 촉진하는 방법은 무엇이 있을까?

# %%
usr = list(df.USER.unique())
# usr  # 고객명단
print('고객 수 : ', len(usr))
# Out:
# 고객 수 :  1229

# %% [markdown]
# ### 1. (한번에 주문한 개수에 따른) 일반/우량 고객 분류

# %%
temp = df.USER.value_counts()
for i in range(1, 12):
    if len(temp[temp.values > i]) != 0:
        print('한번에 {}개 이상 구매(렌트)한 고객 수 : '.format(i+1), len(temp[temp.values > i]))
    else:
        break
# Out:
# 한번에 2개 이상 구매(렌트)한 고객 수 :  139
# 한번에 3개 이상 구매(렌트)한 고객 수 :  50
# 한번에 4개 이상 구매(렌트)한 고객 수 :  17
# 한번에 5개 이상 구매(렌트)한 고객 수 :  9
# 한번에 6개 이상 구매(렌트)한 고객 수 :  8
# 한번에 7개 이상 구매(렌트)한 고객 수 :  5
# 한번에 8개 이상 구매(렌트)한 고객 수 :  3
# 한번에 9개 이상 구매(렌트)한 고객 수 :  3
# 한번에 10개 이상 구매(렌트)한 고객 수 :  2
# 한번에 11개 이상 구매(렌트)한 고객 수 :  1

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=df, x='days',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=df, x='days', hue='p_type',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=df, x='days', hue='sub_type',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=df, x='days', hue='app_yn',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('앱 유입여부')

plt.suptitle('2021년 1분기 전체 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %%
# 2021년 1분기 전체 이용객 분류

f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=df, x='month', order = [1,2,3])
plt.title('월별 주문 건수')

plt.subplot(222)
sns.countplot(data=df, x='month', hue='p_type', order = [1,2,3])
plt.title('p_type별 월별 주문건')

plt.subplot(223)
sns.countplot(data=df, x='month', hue='sub_type', order = [1,2,3])
plt.title('sub_type별 월별 주문건')

plt.subplot(224)
sns.countplot(data=df, x='month', hue='app_yn' ,order = [1,2,3])
plt.title('월별 앱 유입여부')

plt.suptitle('2021년 1분기 전체 월별 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %%
# 2021년 1분기 전체 이용객 분류

f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=df, x='day_type', order=['주중', '휴일'])
plt.title('휴무에 따른 주문 건수')

plt.subplot(222)
sns.countplot(data=df, x='day_type', hue='p_type', order=['주중', '휴일'])
plt.title('p_type별 휴무에 따른 주문건')

plt.subplot(223)
sns.countplot(data=df, x='day_type', hue='sub_type', order=['주중', '휴일'])
plt.title('sub_type별 휴무에 따른 주문건')

plt.subplot(224)
sns.countplot(data=df, x='day_type', hue='app_yn', order=['주중', '휴일'])
plt.title('앱 유입여부')

plt.suptitle('2021년 1분기 전체 휴무에 따른 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# 한번에 10가지 이상의 아이템을 렌트한 고객의 데이터만 따로 살펴보자

# %%
# 10회 이상 구매한 고객 1 
df.query('USER=="a1149461"')
# Out:
#                   brandnm                                           goodsnm  \
# 1144       Alice & Olivia              see-through lace detail blouse black
# 1145               Sandro                embroidery detail lace skirt multi
# 1146                 Time                    draping detail midi skirt gray
# 1147  El estilo de Claire     ruffle detail see-through sleeve blouse black
# 1148            It michaa                  pocket basic pattern skirt green
# 1149               roajeu  ruffle basic pattern mermaid trumpet-skirt green
# 1150       Alexander Wang                          basic pattern skirt grey
# 1151       Christian Dior                    basic pattern sweater burgundy
# 1152                 MSGM                           basic pattern top black
# 1153              Fayewoo     ruffle lace pattern mermaid trumpet-skirt red
# 1154                 Debb                 ribbon basic pattern blouse brown
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 1144  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1145  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1146  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1147  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1148  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1149  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1150  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1151  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1152  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1153  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1154  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
#
#       month  How_long
# 1144      3         2
# 1145      3         2
# 1146      3         2
# 1147      3         2
# 1148      3         2
# 1149      3         2
# 1150      3         2
# 1151      3         2
# 1152      3         2
# 1153      3         2
# 1154      3         2

# %%
# 10회 이상 구매한 고객 2 
df.query('USER=="a1149583"')
# 마찬가지로 하루에 여러 상품 렌트
# 앱 사용 x
# Out:
#                brandnm                               goodsnm      USER  \
# 1098            Theory                one button jacket gray  a1149583
# 1099            Michaa        stitch detail midi skirt white  a1149583
# 1100             Prada               daino shoulder bag skin  a1149583
# 1101         Ted Baker      pleats basic pattern blouse pink  a1149583
# 1102  La maille sezane        frill dots pattern blouse nude  a1149583
# 1103            Michaa  basic pattern A-Line knit-dress nude  a1149583
# 1104            Jigott     button basic pattern blouse white  a1149583
# 1105         It michaa      basic pattern H-Line dress white  a1149583
# 1106              Mine              basic pattern skirt pink  a1149583
# 1107              Mine  punching basic pattern skirt skyblue  a1149583
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 1098  2021-03-16  2021-03-19  4days        O      N  금요일       주중      3
# 1099  2021-03-16  2021-03-19  4days        B      N  금요일       주중      3
# 1100  2021-03-16  2021-03-19  4days       BA      N  금요일       주중      3
# 1101  2021-03-16  2021-03-19  4days        T      N  금요일       주중      3
# 1102  2021-03-16  2021-03-19  4days        T      N  금요일       주중      3
# 1103  2021-03-16  2021-03-19  4days        D      N  금요일       주중      3
# 1104  2021-03-16  2021-03-19  4days        T      N  금요일       주중      3
# 1105  2021-03-16  2021-03-19  4days        D      N  금요일       주중      3
# 1106  2021-03-16  2021-03-19  4days        B      N  금요일       주중      3
# 1107  2021-03-16  2021-03-19  4days        B      N  금요일       주중      3
#
#       How_long
# 1098         3
# 1099         3
# 1100         3
# 1101         3
# 1102         3
# 1103         3
# 1104         3
# 1105         3
# 1106         3
# 1107         3

# %% [markdown]
# 한번에 10개 이상을 구매한 고객 데이터를 살펴보면,
# - 브랜드가 대부분 다르고,
# - sub_type 중복되는 것이 많으며,
# - 렌트기간이 짧다.
#
# 이러한 성향을 보았을 때 평범한 개인(1인) 사용을 위해 렌트한 것으로 보기 어렵다.
# 하루에 여러번 옷을 갈아입을 필요가 있는, 특정한 목적이 있거나, 여러명이 하나의 유저로 함께 렌트한 것으로 예상된다.

# %% [markdown]
# 일반적으로 1~2개의 아이템을 한번에 결제한다고 생각하고, 한번에 3개 이상을 결제/주문하는 고객을 따로 분류하여 분석을 진행한다.
# 여기서 우리는 한번에 3가지 이상 아이템을 구매하는 고객을 우량고객으로 정의하기로 한다.
#
# 한번에 3개 이상 구매(렌트)한 고객은 50명이다.

# %%
temp = df.USER.value_counts()

# 동일한 USER의 행이 3개 이상인 경우 
over3 = list(temp[temp.values > 2].index)

# 3개 이상 이용한 고객들만 뽑은 데이터 프레임
over3_df = df[df.USER==over3[0]]
for i in range(1,len(over3)):
    over3_df = pd.concat([over3_df, df[df.USER==over3[i]]])
over3_df
# Out:
#                   brandnm                                        goodsnm  \
# 1144       Alice & Olivia           see-through lace detail blouse black
# 1145               Sandro             embroidery detail lace skirt multi
# 1146                 Time                 draping detail midi skirt gray
# 1147  El estilo de Claire  ruffle detail see-through sleeve blouse black
# 1148            It michaa               pocket basic pattern skirt green
# ...                   ...                                            ...
# 1418           Since then              flower pattern A-Line dress white
# 1419           Stylenanda          basic pattern H-Line slip-dress black
# 876                Imvely             ruffle flower pattern A-Line dress
# 877            Since then    gather flower pattern A-Line dress burgundy
# 878       & Other Stories       ribbon flower pattern A-Line dress multi
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 1144  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1145  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1146  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1147  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1148  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1418  a1131410  2020-11-18  2021-03-03  4days        D      Y  수요일       주중
# 1419  a1131410  2020-11-18  2021-03-03  4days        D      N  수요일       주중
# 876   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
# 877   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
# 878   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
#
#       month  How_long
# 1144      3         2
# 1145      3         2
# 1146      3         2
# 1147      3         2
# 1148      3         2
# ...     ...       ...
# 1418      3       105
# 1419      3       105
# 876       3         0
# 877       3         0
# 878       3         0
#
# [198 rows x 12 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=over3_df, x='days',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=over3_df, x='days', hue='p_type',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=over3_df, x='days', hue='sub_type',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=over3_df, x='days', hue='app_yn',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('앱 유입여부')

plt.suptitle('2021년 1분기 우량 고객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %%
a = df['USER'].value_counts()
# 3개 이상 이용한 고객의 선호 브랜드

more3 = list(a[a.values > 2].index)
more3

more3_df = df[df['USER']==more3[0]]

for i in range(1,len(more3)):
    more3_df = pd.concat([more3_df, df[df['USER']==more3[i]]])
more3_df
# Out:
#                   brandnm                                        goodsnm  \
# 1144       Alice & Olivia           see-through lace detail blouse black
# 1145               Sandro             embroidery detail lace skirt multi
# 1146                 Time                 draping detail midi skirt gray
# 1147  El estilo de Claire  ruffle detail see-through sleeve blouse black
# 1148            It michaa               pocket basic pattern skirt green
# ...                   ...                                            ...
# 1418           Since then              flower pattern A-Line dress white
# 1419           Stylenanda          basic pattern H-Line slip-dress black
# 876                Imvely             ruffle flower pattern A-Line dress
# 877            Since then    gather flower pattern A-Line dress burgundy
# 878       & Other Stories       ribbon flower pattern A-Line dress multi
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 1144  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1145  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1146  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# 1147  a1149461  2021-03-15  2021-03-17  4days        T      N  수요일       주중
# 1148  a1149461  2021-03-15  2021-03-17  4days        B      N  수요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1418  a1131410  2020-11-18  2021-03-03  4days        D      Y  수요일       주중
# 1419  a1131410  2020-11-18  2021-03-03  4days        D      N  수요일       주중
# 876   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
# 877   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
# 878   a1151410  2021-03-30  2021-03-30  4days        D      Y  화요일       주중
#
#       month  How_long
# 1144      3         2
# 1145      3         2
# 1146      3         2
# 1147      3         2
# 1148      3         2
# ...     ...       ...
# 1418      3       105
# 1419      3       105
# 876       3         0
# 877       3         0
# 878       3         0
#
# [198 rows x 12 columns]

# %%
len(more3_df['USER'].unique())
# Out:
# 50

# %%
print("전체 고객 중 우량 고객의 데이터 비율 :", round((len(more3_df)/len(df)),2)*100,"%")
print("전체 고객 중 우량 고객의 비율 :", round((more3_df['USER'].nunique()/df['USER'].nunique()),2)*100,"%")
# Out:
# 전체 고객 중 우량 고객의 데이터 비율 : 14.000000000000002 %
# 전체 고객 중 우량 고객의 비율 : 4.0 %

# %%
# 3개 이상 이용한 고객의 선호 브랜드
more3_df.brandnm.value_counts(ascending=False).head(10)
# Out:
# Mixed                  8
# El estilo de Claire    6
# Burberry               6
# Max Mara               6
# Christian Dior         5
# Burberry London        5
# Saint Laurent          5
# Balmain                4
# Michaa                 4
# Sandro                 4
# Name: brandnm, dtype: int64

# %% [markdown]
# **'Mixed'는 상.하의가 서로 다른 브랜드의 조합으로 당초 데이터에서는 결측값으로 처리되었으나, 임의로 부여한 값이다.

# %%
df[df.brandnm == 'Mixed']
# Out:
#      brandnm                                            goodsnm      USER  \
# 146    Mixed  feminine military blouse & high waist wide slacks  a1144948
# 147    Mixed  button basic pattern doublebreasted-jacket sky...   a170041
# 160    Mixed  lace point shirring blouse pink & lace detail ...  a1141009
# 220    Mixed  printing pattern hoodie grey & pocket basic pa...  a1144470
# 266    Mixed  button basic pattern jacket black & pocket bas...   a121913
# 281    Mixed      buckle shirt & embroidery lace skirt charcoal  a1132297
# 284    Mixed  button tweed pattern doublebreasted-coat multi...  a1127979
# 328    Mixed  long sleeve rib t-shirt & check pattern square...  a1134915
# 341    Mixed         cutout neck knit & color pleats belt skirt  a1141257
# 366    Mixed  El estilo de Claire - neoprene botanical print...  a1107090
# 371    Mixed              frill detail knit & dot pattern skirt   a171081
# 441    Mixed  stripe boat neck t-shirt & buckle suspender dress  a1147458
# 503    Mixed  stripe pattern long vest gray & wrap detail st...  a1145316
# 523    Mixed       no collar simple jacket& crease slacks ivory  a1146852
# 524    Mixed  button check pattern jacket yellow & pocket ch...  a1146852
# 542    Mixed                waffle bulky knit & wool slim skirt  a1146854
# 761    Mixed  [66]El estilo de Claire - wang letter neoprene...  a1139388
# 762    Mixed           embroidery twist knit & mini gored skirt  a1139388
# 875    Mixed  ribbon flower pattern blouse black & pleats fl...  a1149885
# 888    Mixed               color lace blouse & color lace skirt   a110947
# 927    Mixed     shoulder button pullover & burnout flare skirt  a1150959
# 942    Mixed  cut out detail button pointed top & stripe pat...  a1150675
# 953    Mixed  button stripe pattern wool jacket black & pock...  a1124921
# 989    Mixed  embossing detail crop jacket & pleats detail p...   a174425
# 1058   Mixed  lettering pattern top mint & pocket basic patt...  a1150312
# 1156   Mixed  button basic pattern cardigan pink & basic pat...  a1147111
# 1206   Mixed    lace pattern top pink & lace pattern skirt pink  a1149269
# 1380   Mixed  button check pattern jacket brown & pocket che...  a1148229
# 1400   Mixed  ribbon flower pattern top navy & flower patter...  a1147799
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 146   2021-01-30  2021-01-30  4days       TP      Y  토요일       휴일      1
# 147   2020-01-01  2021-01-30  4days       TP      Y  토요일       휴일      1
# 160   2021-01-04  2021-01-28  4days       TP      Y  목요일       주중      1
# 220   2021-01-25  2021-01-26  4days       TP      Y  화요일       주중      1
# 266   2019-05-05  2021-01-21  4days       TP      Y  목요일       주중      1
# 281   2020-11-22  2021-01-21  7days       TP      Y  목요일       주중      1
# 284   2020-10-31  2021-01-21  7days       TP      Y  목요일       주중      1
# 328   2020-12-03  2021-01-19  7days       TP      N  화요일       주중      1
# 341   2021-01-05  2021-01-19  4days       TP      Y  화요일       주중      1
# 366   2020-07-03  2021-01-17  4days       TP      Y  일요일       휴일      1
# 371   2020-01-06  2021-01-17  7days       TP      Y  일요일       휴일      1
# 441   2021-02-24  2021-02-24  7days       TP      Y  수요일       주중      2
# 503   2021-02-03  2021-02-22  4days       TP      Y  월요일       주중      2
# 523   2021-02-18  2021-02-19  7days       TP      N  금요일       주중      2
# 524   2021-02-18  2021-02-19  7days       TP      N  금요일       주중      2
# 542   2021-02-18  2021-02-18  7days       TP      Y  목요일       주중      2
# 761   2020-12-23  2021-02-04  4days       TP      Y  목요일       주중      2
# 762   2020-12-23  2021-02-04  4days       TP      Y  목요일       주중      2
# 875   2021-03-18  2021-03-30  4days       TP      Y  화요일       주중      3
# 888   2018-11-01  2021-03-29  7days       TP      Y  월요일       주중      3
# 927   2021-03-26  2021-03-26  4days       TP      N  금요일       주중      3
# 942   2021-03-24  2021-03-26  7days       TP      Y  금요일       주중      3
# 953   2020-10-17  2021-03-25  4days       TP      Y  목요일       주중      3
# 989   2020-01-16  2021-03-24  4days       TP      Y  수요일       주중      3
# 1058  2021-03-22  2021-03-22  4days       TP      Y  월요일       주중      3
# 1156  2021-02-21  2021-03-17  4days       TP      Y  수요일       주중      3
# 1206  2021-03-14  2021-03-16  4days       TP      N  화요일       주중      3
# 1380  2021-03-04  2021-03-04  4days       TP      N  목요일       주중      3
# 1400  2021-02-28  2021-03-03  7days       TP      Y  수요일       주중      3
#
#       How_long
# 146          0
# 147        395
# 160         24
# 220          1
# 266        627
# 281         60
# 284         82
# 328         47
# 341         14
# 366        198
# 371        377
# 441          0
# 503         19
# 523          1
# 524          1
# 542          0
# 761         43
# 762         43
# 875         12
# 888        879
# 927          0
# 942          2
# 953        159
# 989        433
# 1058         0
# 1156        24
# 1206         2
# 1380         0
# 1400         3

# %% [markdown]
# 그렇다면, 1~2개를 구입하는 일반적인 패턴을 보이는 한번에 3개 이상의 아이템을 구매하는 우량 고객간의 선호 브랜드는 어떻게 다를까?

# %%
temp = df.USER.value_counts()

# 한번에 1~2개만 빌린 고객들
under3 = list(temp[temp.values <= 2].index)

# 일반 고객들만 뽑은 데이터 프레임
under3_df = df[df.USER==under3[0]]
for i in range(1,len(under3)):
    under3_df = pd.concat([under3_df, df[df.USER==under3[i]]])
under3_df.head()
# Out:
#               brandnm                                  goodsnm     USER  \
# 1276  Cesare Paciotti                             fonte clutch  a111030
# 1277   Andersson Bell  pocket basic pattern H-Line dress khaki  a111030
# 493            Ambush            high neck hoodie jumper black  a153797
# 494           Miu Miu           matelasse cross body bag black  a153797
# 273        Balenciaga                     ville logo bag white  a172349
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 1276  2018-11-03  2021-03-11  4days       BA      N  목요일       주중      3
# 1277  2018-11-03  2021-03-11  4days        D      N  목요일       주중      3
# 493   2019-11-04  2021-02-22  4days        O      Y  월요일       주중      2
# 494   2019-11-04  2021-02-22  4days       BA      Y  월요일       주중      2
# 273   2020-01-10  2021-01-21  4days       BA      Y  목요일       주중      1
#
#       How_long
# 1276       859
# 1277       859
# 493        476
# 494        476
# 273        377

# %%
over3_df_br = over3_df.brandnm.value_counts().sort_values(ascending=False).head(10) # 우량고객
under3_df_br = under3_df.brandnm.value_counts().sort_values(ascending=False).head(10) # 일반고객

plt.subplots(2,1,figsize=(20,12))
plt.subplot(211)
sns.barplot(over3_df_br.index, over3_df_br.values, palette='dark')
plt.title('우량고객 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)

plt.subplot(212)
sns.barplot(under3_df_br.index, under3_df_br.values)
plt.title('일반고객 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %% [markdown]
# >**일반고객 상위 1 구찌는 우량고객기준 브랜드 상위10 안에 나타나지 않음
# 상하의 혼합하여 사용하는 경우(Mixed)가 선호1로 나타남**
#
# >**일반고객과 우량고객 상위10 중복된 브랜드는**
# - Saint Laurent, Burberry, Thom Browne

# %%
# 우량고객 월별
more3_df_m1 = more3_df.loc[more3_df['month'] == 1]
more3_df_m2 = more3_df.loc[more3_df['month'] == 2]
more3_df_m3 = more3_df.loc[more3_df['month'] == 3]

print('우량고객의 1월 구매건수 :', len(more3_df_m1))
print('우량고객의 2월 구매건수 :',len(more3_df_m2))
print('우량고객의 3월 구매건수 :',len(more3_df_m3))
# Out:
# 우량고객의 1월 구매건수 : 63
# 우량고객의 2월 구매건수 : 57
# 우량고객의 3월 구매건수 : 78

# %%
more3_df_m1_br = more3_df_m1['brandnm'].value_counts().sort_values(ascending=False).head(10) # 우량 1월 브랜드
more3_df_m2_br = more3_df_m2['brandnm'].value_counts().sort_values(ascending=False).head(10) # 우량 2월 브랜드
more3_df_m3_br = more3_df_m3['brandnm'].value_counts().sort_values(ascending=False).head(10) # 우량 3월 브랜드

plt.subplots(3,1,figsize=(25,20))
plt.subplot(311)
sns.barplot(more3_df_m1_br.index, more3_df_m1_br.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('우량고객 1월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)

plt.subplot(312)
sns.barplot(more3_df_m2_br.index, more3_df_m2_br.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('우량고객 2월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)

plt.subplot(313)
sns.barplot(more3_df_m3_br.index, more3_df_m3_br.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('우량고객 3월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >1월 상위 top3
# - Burberry, Mixed, Saint Laurant
#
# >2월 상위 top3
# - Mixed, Convexo Concave, Christian Dior
#
# >3월 상위 top3
# - Mine, Sandro, Saint Laurent

# %% [markdown]
# 우량고객 전체에서 선호 top1이었던 Mixed는 3월에서는 top10안에 전혀 들지 않음
# 월별로 선호하는 브랜드가 있는걸까? (브랜드마다 계절 의류 보유수에 따라 다를까?)

# %%
# 우량고객이 1월에  가장 선호하는 카테고리 top 5
more3_df_m1['sub_type'].value_counts().head()
# Out:
# T     21
# D     15
# O     13
# BA     6
# B      6
# Name: sub_type, dtype: int64

# %%
# 우량고객이 1월에  가장 선호하는 카테고리 top 5
more3_df_m2['sub_type'].value_counts().head()
# Out:
# O     15
# D     14
# BA    10
# T      9
# TP     5
# Name: sub_type, dtype: int64

# %%
# 우량고객이 1월에  가장 선호하는 카테고리 top 5
more3_df_m3['sub_type'].value_counts().head()
# Out:
# B     22
# D     21
# T     20
# O      9
# BA     5
# Name: sub_type, dtype: int64

# %%
more3_df_m1_sub = more3_df_m1['sub_type'].value_counts().sort_values(ascending=False) # 우량 1월 카테고리
more3_df_m2_sub = more3_df_m2['sub_type'].value_counts().sort_values(ascending=False) # 우량 2월 카테고리
more3_df_m3_sub = more3_df_m3['sub_type'].value_counts().sort_values(ascending=False) # 우량 3월 카테고리

plt.subplots(3,1,figsize=(25,20))
plt.subplot(311)
sns.barplot(more3_df_m1_sub.index, more3_df_m1_sub.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('우량고객 1월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)

plt.subplot(312)
sns.barplot(more3_df_m2_sub.index, more3_df_m2_sub.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('우량고객 2월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)

plt.subplot(313)
sns.barplot(more3_df_m3_sub.index, more3_df_m3_sub.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('우량고객 3월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >1월과 2월에는 아우터의 구매건이 많은 편이었으며, 3월에는 아우터의 수요가 줄었음
# 계절에 따른 카테고리별 구매건이 달라짐을 알 수 있음
# 드레스의 수요는 계절과 상관없이 높음

# %%
more3_df_m1_p = more3_df_m1['p_type'].value_counts().sort_values(ascending=False) # 우량 1월 상품
more3_df_m2_p = more3_df_m2['p_type'].value_counts().sort_values(ascending=False) # 우량 2월 상품
more3_df_m3_p = more3_df_m3['p_type'].value_counts().sort_values(ascending=False) # 우량 3월 상품

plt.subplots(1,3,figsize=(15,5))
plt.subplot(131)
sns.barplot(more3_df_m1_p.index, more3_df_m1_p.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('우량고객 1월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)

plt.subplot(132)
sns.barplot(more3_df_m2_p.index, more3_df_m2_p.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('우량고객 2월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)

plt.subplot(133)
sns.barplot(more3_df_m3_p.index, more3_df_m3_p.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('우량고객 3월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >**상품 사용은 4일권이 가장 많고, 1월부터 3월까지 늘어난 우량고객의 구매건수만큼 4일권의 구매도 늘었지만,
# 7일권 구매는 큰 변화가 없음**

# %%
more3_df_m1_day = more3_df_m1['days'].value_counts().sort_values(ascending=False) # 우량 1월 요일
more3_df_m2_day = more3_df_m2['days'].value_counts().sort_values(ascending=False) # 우량 2월 요일
more3_df_m3_day = more3_df_m3['days'].value_counts().sort_values(ascending=False) # 우량 3월 요일

plt.subplots(1,3,figsize=(15,5))
plt.subplot(131)
sns.barplot(more3_df_m1_day.index, more3_df_m1_day.values, palette='dark',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('우량고객 1월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)

plt.subplot(132)
sns.barplot(more3_df_m2_day.index, more3_df_m2_day.values, palette='muted',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('우량고객 2월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)

plt.subplot(133)
sns.barplot(more3_df_m3_day.index, more3_df_m3_day.values, palette='colorblind',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('우량고객 3월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >**1월부터 3월까지 요일별 결제건수가 다름
# 1월에는 목,월,금
# 2월에는 금,월,수
# 3월에는 수요일에 결제건수가 압도적으로 많음**
#
# >**결제 후, 배송까지 하루가 걸린다고 가정하면 1월과 2월은
# 상품 중 4일권을 예로 들면, 금요일-월요일/ 화요일-금요일 -> 주말사용, 평일사용 골고루 분포되어 있음
# 3월은 목요일-일요일 즉 주말사용이 늘었음**

# %%
print(len(more3_df['reg_date'].unique()))
more3_df['reg_date'].unique()
# Out:
# 43
# array(['2021-03-15', '2021-03-16', '2021-01-13', '2021-01-18',
#        '2020-03-20', '2020-03-11', '2020-11-09', '2021-01-01',
#        '2020-12-23', '2020-12-21', '2021-03-13', '2021-02-18',
#        '2019-11-23', '2021-01-26', '2021-02-14', '2021-03-23',
#        '2020-03-09', '2021-03-24', '2020-12-04', '2020-12-22',
#        '2020-09-14', '2021-03-22', '2019-03-09', '2021-02-17',
#        '2020-02-19', '2021-02-25', '2021-02-08', '2020-11-12',
#        '2020-04-17', '2021-01-04', '2021-02-05', '2021-03-01',
#        '2021-01-20', '2021-01-07', '2021-02-03', '2021-02-01',
#        '2021-02-06', '2021-01-02', '2021-02-02', '2021-01-25',
#        '2020-11-23', '2020-11-18', '2021-03-30'], dtype=object)

# %% [markdown]
# 2016년 9월 클로젯셰어 오픈
# 우량고객의 가입일 2021년이 가장 많다.

# %% [markdown]
# ### 2. (특정일자 기준) 기존 vs 신규 유저 분류
#
# - 올해부터 가입한 사람부터 신규 유저로 정의

# %%
new_usr = df[df.reg_date > '2020-12-31']
new_usr
# Out:
#                   brandnm                                      goodsnm  \
# 1     El estilo de Claire                   beads cropped jacket black
# 2                   Danha    embroidery point oriental mini skirt blue
# 3                   Danha                    graphics pattern top pink
# 4         Burberry London       buckle basic pattern zipup-jumper navy
# 8                   Gucci                           dionysus cross bag
# ...                   ...                                          ...
# 1459      Burberry London  embroidery basic pattern wool sweater brown
# 1460           London Fog               button basic pattern coat grey
# 1462                Prada                          saffiano lux M gray
# 1463             Burberry                  basic pattern sweater beige
# 1464               Chanel          graphics pattern sweat-shirts white
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 1     a1140859  2021-01-02  2021-01-15  4days        O      N  금요일       주중
# 2     a1140859  2021-01-02  2021-01-15  4days        B      N  금요일       주중
# 3     a1140859  2021-01-02  2021-01-15  4days        T      N  금요일       주중
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y  금요일       주중
# 8     a1143028  2021-01-14  2021-01-15  4days       BA      Y  금요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1459  a1147932  2021-03-01  2021-03-01  4days        T      Y  공휴일       휴일
# 1460  a1147932  2021-03-01  2021-03-01  4days        O      Y  공휴일       휴일
# 1462  a1146069  2021-02-11  2021-03-01  7days       BA      Y  공휴일       휴일
# 1463  a1147848  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1464  a1147788  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
#
#       month  How_long
# 1         1        13
# 2         1        13
# 3         1        13
# 4         1        14
# 8         1         1
# ...     ...       ...
# 1459      3         0
# 1460      3         0
# 1462      3        18
# 1463      3         1
# 1464      3         1
#
# [981 rows x 12 columns]

# %%
old_usr = df[df.reg_date <= '2020-12-31']
old_usr
# Out:
#                  brandnm                                  goodsnm      USER  \
# 0                  Gucci       flower dionysus shoulder bag beige   a161237
# 5                  Prada                  ruffle detail long coat   a110231
# 6               Max Mara      strap basic pattern wrap-coat black  a1139960
# 7              Molliolli     pocket basic pattern fur-outer ivory   a115159
# 9                 Sandro           pattern pointed cardigan black   a117306
# ...                  ...                                      ...       ...
# 1449            Burberry  button basic pattern wool cardigan grey   a163815
# 1454               Gucci      marmont gg logo quilted bag Black 2   a177034
# 1457            Max Mara            zipper detail two tone jacket   a112319
# 1461  Yves Saint Laurent               logo point clutch bag pink   a119721
# 1465            Burberry                classic trench coat beige   a190054
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 0     2019-12-06  2021-01-15  7days       BA      Y  금요일       주중      1
# 5     2018-10-18  2021-01-15  7days        O      Y  금요일       주중      1
# 6     2020-12-26  2021-01-15  7days        O      Y  금요일       주중      1
# 7     2019-01-29  2021-01-15  4days        O      Y  금요일       주중      1
# 9     2019-03-02  2021-01-15  7days        O      Y  금요일       주중      1
# ...          ...         ...    ...      ...    ...  ...      ...    ...
# 1449  2019-12-12  2021-03-01  7days        O      Y  공휴일       휴일      3
# 1454  2020-01-23  2021-03-01  4days       BA      Y  공휴일       휴일      3
# 1457  2018-11-29  2021-03-01  4days        O      Y  공휴일       휴일      3
# 1461  2019-04-10  2021-03-01  7days       BA      Y  공휴일       휴일      3
# 1465  2020-03-24  2021-03-01  4days        O      Y  공휴일       휴일      3
#
#       How_long
# 0          406
# 5          820
# 6           20
# 7          717
# 9          685
# ...        ...
# 1449       445
# 1454       403
# 1457       823
# 1461       691
# 1465       342
#
# [485 rows x 12 columns]

# %%
new_usr.USER.nunique()
old_usr.USER.nunique()
print('전체 가입자중 신규고객은 {}명, 기존고객은 {}명이다.'.format(new_usr.USER.nunique(), old_usr.USER.nunique()))
# Out:
# 전체 가입자중 신규고객은 830명, 기존고객은 399명이다.

# %% [markdown]
# 전체 고객중 2/3가 넘는 고객이 2021년 가입한 신규고객으로 전체데이터에 대한 분석과 신규고객에 대한 분석이 비슷한 양상을 보일 것으로 예상된다.

# %%
# 2021년 가입자 선호 브랜드
new_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 166
# Saint Laurent          66
# Chanel                 65
# Louis Vuitton          61
# Prada                  36
# Burberry               33
# Yves Saint Laurent     24
# Celine                 22
# Fendi                  19
# Thom Browne            19
# Name: brandnm, dtype: int64

# %%
# 2021년 이전 가입자 선호 브랜드
old_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 64
# Chanel                25
# Prada                 22
# Saint Laurent         20
# Burberry              20
# Louis Vuitton         18
# Yves Saint Laurent    14
# Thom Browne           14
# Mixed                 12
# Max Mara              12
# Name: brandnm, dtype: int64

# %%
new_br = new_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
old_br = old_usr.brandnm.value_counts().sort_values(ascending=False).head(10)

plt.subplots(2,1,figsize=(20,12))
plt.subplot(211)
sns.barplot(new_br.index, new_br.values, palette='dark')
plt.title('신규 유저 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)

plt.subplot(212)
sns.barplot(old_br.index, old_br.values)
plt.title('기존 유저 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=new_usr, x='days',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=new_usr, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=new_usr, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=new_usr, x='days', hue='app_yn',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 앱 유입여부')

plt.suptitle('신규(2021년 이후) 가입자 동향',fontsize=30, fontweight = 'bold')
plt.show()

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=old_usr, x='days',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=old_usr, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=old_usr, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=old_usr, x='days', hue='app_yn',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.title('요일별 앱 유입여부')

plt.suptitle('기존(2021이전) 가입자 동향',fontsize=30, fontweight = 'bold')
plt.show()

# %%
# 신규고객 그룹 월별 분류
new_usr_m1 = new_usr.loc[new_usr['month'] == 1]
new_usr_m2 = new_usr.loc[new_usr['month'] == 2]
new_usr_m3 = new_usr.loc[new_usr['month'] == 3]

print('신규고객의 1월 구매건수 :', len(new_usr_m1))
print('신규고객의 2월 구매건수 :',len(new_usr_m2))
print('신규고객의 3월 구매건수 :',len(new_usr_m3))
# Out:
# 신규고객의 1월 구매건수 : 195
# 신규고객의 2월 구매건수 : 330
# 신규고객의 3월 구매건수 : 456

# %%
new_usr_m1_br = new_usr_m1['brandnm'].value_counts().sort_values(ascending=False).head(10) # 1월 브랜드
new_usr_m2_br = new_usr_m2['brandnm'].value_counts().sort_values(ascending=False).head(10) # 2월 브랜드
new_usr_m3_br = new_usr_m3['brandnm'].value_counts().sort_values(ascending=False).head(10) # 3월 브랜드

plt.subplots(3,1,figsize=(25,20))
plt.subplot(311)
sns.barplot(new_usr_m1_br.index, new_usr_m1_br.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('신규고객 1월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)

plt.subplot(312)
sns.barplot(new_usr_m2_br.index, new_usr_m2_br.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('신규고객 2월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)

plt.subplot(313)
sns.barplot(new_usr_m3_br.index, new_usr_m3_br.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('신규고객 3월 상위 10개 브랜드', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('브랜드', fontsize=20)
plt.tight_layout()
plt.show()

# %%
new_usr_m1_sub = new_usr_m1['sub_type'].value_counts().sort_values(ascending=False) # 1월 카테고리
new_usr_m2_sub = new_usr_m2['sub_type'].value_counts().sort_values(ascending=False) # 2월 카테고리
new_usr_m3_sub = new_usr_m3['sub_type'].value_counts().sort_values(ascending=False) # 3월 카테고리

plt.subplots(3,1,figsize=(25,20))
plt.subplot(311)
sns.barplot(new_usr_m1_sub.index, new_usr_m1_sub.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('신규고객 1월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)

plt.subplot(312)
sns.barplot(new_usr_m2_sub.index, new_usr_m2_sub.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('신규고객 2월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)

plt.subplot(313)
sns.barplot(new_usr_m3_sub.index, new_usr_m3_sub.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('신규고객 3월 카테고리', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('카테고리', fontsize=20)
plt.tight_layout()
plt.show()

# %%
new_usr_m1_p = new_usr_m1['p_type'].value_counts().sort_values(ascending=False) # 1월 상품
new_usr_m2_p = new_usr_m2['p_type'].value_counts().sort_values(ascending=False) # 2월 상품
new_usr_m3_p = new_usr_m3['p_type'].value_counts().sort_values(ascending=False) # 3월 상품

plt.subplots(1,3,figsize=(15,5))
plt.subplot(131)
sns.barplot(new_usr_m1_p.index, new_usr_m1_p.values, palette='dark')
plt.xticks(fontsize=20)
plt.title('신규고객 1월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)

plt.subplot(132)
sns.barplot(new_usr_m2_p.index, new_usr_m2_p.values, palette='muted')
plt.xticks(fontsize=20)
plt.title('신규고객 2월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)

plt.subplot(133)
sns.barplot(new_usr_m3_p.index, new_usr_m3_p.values, palette='colorblind')
plt.xticks(fontsize=20)
plt.title('신규고객 3월 상품', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('상품(p-type)', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >2월과 3월에는 상대적으로 7일권 상품을 사용하는 경우가 늘었음

# %%
new_usr_m1_day = new_usr_m1['days'].value_counts().sort_values(ascending=False) # 1월 요일
new_usr_m2_day = new_usr_m2['days'].value_counts().sort_values(ascending=False) # 2월 요일
new_usr_m3_day = new_usr_m3['days'].value_counts().sort_values(ascending=False) # 3월 요일

plt.subplots(1,3,figsize=(15,5))
plt.subplot(131)
sns.barplot(new_usr_m1_day.index, new_usr_m1_day.values, palette='dark',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('신규고객 1월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)

plt.subplot(132)
sns.barplot(new_usr_m2_day.index, new_usr_m2_day.values, palette='muted',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('신규고객 2월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)

plt.subplot(133)
sns.barplot(new_usr_m3_day.index, new_usr_m3_day.values, palette='colorblind',
             order=['월요일','화요일','수요일','목요일','금요일','토요일','일요일', '공휴일'])
plt.xticks(fontsize=10)
plt.title('신규고객 3월 요일별 구매건수', fontsize=25)
plt.ylabel('판매량(count)', fontsize=20)
plt.xlabel('요일', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# >**1월에는 목요일에 빌리는 경우가 월등히 많음
# 1월에는 4일권을 사용하는 경우가 많았기 때문에
# 금요일 포함 주말을 사용하고 반납하려는 의도가 보임**
#
# >**2월과 3월에는 상대적으로 7일권을 사용하는 경우가 많았던 것을 고려하면,
# 주초에 빌려서 주말까지 사용하는 의도일 것으로 예상됨**
