# %%
import pandas as pd

dt = pd.read_csv('./data/clsoet_share_bags.csv').drop('Unnamed: 0',axis=1)
cs_dt = pd.read_excel('./data/클로젯셰어_과제DB 대체 자료.xlsx')

dt.columns = ['brandnm', 'goodsnm', '4days', '7days']

display(dt)
display(cs_dt)
# Out:
#            brandnm                                 goodsnm  4days  7days
# 0    LOUIS VUITTON  monogram speedy 40 mini tote bag brown  49000  59000
# 1            FENDI          rogo buckle baguette bag brown  39000  49000
# 2            GUCCI   quilted mammont chain cross bag black  49000  59000
# 3            GUCCI               flower pattern clutch bag  49000  59000
# 4           CHANEL                    classic clutch black  49000  59000
# ..             ...                                     ...    ...    ...
# 124          GUCCI                     ophidia small black  39000  49000
# 125        MIU MIU            matelasse shoulder bag black  39000  49000
# 126          GUCCI                dionysus cross bag green  39000  49000
# 127         CHANEL           zipper detail bucket tote bag  49000  59000
# 128         CELINE                             trio L pink  49000  59000
#
# [129 rows x 4 columns]
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER   reg_date order_date p_type sub_type app_yn
# 0      a161237 2019-12-06 2021-01-15  7days       BA      Y
# 1     a1140859 2021-01-02 2021-01-15  4days        O    NaN
# 2     a1140859 2021-01-02 2021-01-15  4days        B    NaN
# 3     a1140859 2021-01-02 2021-01-15  4days        T    NaN
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y
# ...        ...        ...        ...    ...      ...    ...
# 1466   a119721 2019-04-10 2021-03-01  7days       BA      Y
# 1467  a1146069 2021-02-11 2021-03-01  7days       BA      Y
# 1468  a1147848 2021-02-28 2021-03-01  7days        T      Y
# 1469  a1147788 2021-02-28 2021-03-01  7days        T      Y
# 1470   a190054 2020-03-24 2021-03-01  4days        O      Y
#
# [1471 rows x 8 columns]

# %% [markdown]
# # dt와 cs_dt join : left

# %%
merge_dt = pd.merge(dt, cs_dt, how='right', on=['brandnm','goodsnm'])
merge_dt
# Out:
#                   brandnm                                      goodsnm  4days  \
# 0                   Gucci           flower dionysus shoulder bag beige    NaN
# 1                   Gucci           flower dionysus shoulder bag beige    NaN
# 2     El estilo de Claire                   beads cropped jacket black    NaN
# 3                   Danha    embroidery point oriental mini skirt blue    NaN
# 4                   Danha                    graphics pattern top pink    NaN
# ...                   ...                                          ...    ...
# 1466      Burberry London  embroidery basic pattern wool sweater brown    NaN
# 1467           London Fog               button basic pattern coat grey    NaN
# 1468   Yves Saint Laurent                   logo point clutch bag pink    NaN
# 1469             Burberry                  basic pattern sweater beige    NaN
# 1470               Chanel          graphics pattern sweat-shirts white    NaN
#
#       7days      USER   reg_date order_date p_type sub_type app_yn
# 0       NaN   a161237 2019-12-06 2021-01-15  7days       BA      Y
# 1       NaN   a156236 2019-11-15 2021-03-26  4days       BA      Y
# 2       NaN  a1140859 2021-01-02 2021-01-15  4days        O    NaN
# 3       NaN  a1140859 2021-01-02 2021-01-15  4days        B    NaN
# 4       NaN  a1140859 2021-01-02 2021-01-15  4days        T    NaN
# ...     ...       ...        ...        ...    ...      ...    ...
# 1466    NaN  a1147932 2021-03-01 2021-03-01  4days        T      Y
# 1467    NaN  a1147932 2021-03-01 2021-03-01  4days        O      Y
# 1468    NaN   a119721 2019-04-10 2021-03-01  7days       BA      Y
# 1469    NaN  a1147848 2021-02-28 2021-03-01  7days        T      Y
# 1470    NaN  a1147788 2021-02-28 2021-03-01  7days        T      Y
#
# [1471 rows x 10 columns]

# %%
merge_dt.isnull().sum()
# Out:
# brandnm         29
# goodsnm          0
# 4days         1471
# 7days         1471
# USER             0
# reg_date         5
# order_date       0
# p_type           0
# sub_type         0
# app_yn         176
# dtype: int64

# %%
#merge_dt[merge_dt['brandnm'].isnull()]

# %% [markdown]
# # inner join

# %%
inner_dt = pd.merge(cs_dt, dt, how='inner', on='goodsnm')
inner_dt.drop('brandnm_y', axis=1, inplace=True)

# %%
an = inner_dt.app_yn.fillna('N')
inner_dt['app_yn'] = an
inner_dt
# Out:
#          brandnm_x                                  goodsnm      USER  \
# 0            Fendi  stripe pattern two way bucket bag brown  a1142679
# 1            Fendi  stripe pattern two way bucket bag brown  a1151466
# 2            Fendi  stripe pattern two way bucket bag brown  a1110964
# 3            Gucci                     flap cross bag black  a1141099
# 4            Gucci                     flap cross bag black  a1151181
# ..             ...                                      ...       ...
# 154         Hermes           fabric fourre tout MM tote bag   a197203
# 155  Louis Vuitton               studded shoulder bag black  a1123025
# 156         Chanel         chevron quilted clutch bag black  a1149790
# 157          Gucci                  monogram backpack brown  a1149535
# 158          Gucci           GG soho chain clutch bag black  a1147854
#
#       reg_date order_date p_type sub_type app_yn  4days  7days
# 0   2021-01-13 2021-01-14  7days       BA      Y  49000  59000
# 1   2021-03-31 2021-03-31  7days       BA      Y  49000  59000
# 2   2020-08-10 2021-03-15  4days       BA      N  49000  59000
# 3   2021-01-04 2021-01-13  4days       BA      Y  49000  59000
# 4   2021-03-28 2021-03-31  7days       BA      Y  49000  59000
# ..         ...        ...    ...      ...    ...    ...    ...
# 154 2020-04-19 2021-03-18  7days       BA      N  39000  49000
# 155 2020-10-07 2021-03-18  7days       BA      Y  39000  49000
# 156 2021-03-17 2021-03-18  7days       BA      Y  49000  59000
# 157 2021-03-16 2021-03-16  7days       BA      N  49000  59000
# 158 2021-02-28 2021-03-09  4days       BA      Y  49000  59000
#
# [159 rows x 10 columns]

# %%
inner_dt.columns = ['brandnm', 'goodsnm', 'USER', 'reg_date' ,'order_date', 'p_type', 'sub_type', 'app_yn', '4days', '7days']
inner_dt
# Out:
#            brandnm                                  goodsnm      USER  \
# 0            Fendi  stripe pattern two way bucket bag brown  a1142679
# 1            Fendi  stripe pattern two way bucket bag brown  a1151466
# 2            Fendi  stripe pattern two way bucket bag brown  a1110964
# 3            Gucci                     flap cross bag black  a1141099
# 4            Gucci                     flap cross bag black  a1151181
# ..             ...                                      ...       ...
# 154         Hermes           fabric fourre tout MM tote bag   a197203
# 155  Louis Vuitton               studded shoulder bag black  a1123025
# 156         Chanel         chevron quilted clutch bag black  a1149790
# 157          Gucci                  monogram backpack brown  a1149535
# 158          Gucci           GG soho chain clutch bag black  a1147854
#
#       reg_date order_date p_type sub_type app_yn  4days  7days
# 0   2021-01-13 2021-01-14  7days       BA      Y  49000  59000
# 1   2021-03-31 2021-03-31  7days       BA      Y  49000  59000
# 2   2020-08-10 2021-03-15  4days       BA      N  49000  59000
# 3   2021-01-04 2021-01-13  4days       BA      Y  49000  59000
# 4   2021-03-28 2021-03-31  7days       BA      Y  49000  59000
# ..         ...        ...    ...      ...    ...    ...    ...
# 154 2020-04-19 2021-03-18  7days       BA      N  39000  49000
# 155 2020-10-07 2021-03-18  7days       BA      Y  39000  49000
# 156 2021-03-17 2021-03-18  7days       BA      Y  49000  59000
# 157 2021-03-16 2021-03-16  7days       BA      N  49000  59000
# 158 2021-02-28 2021-03-09  4days       BA      Y  49000  59000
#
# [159 rows x 10 columns]

# %%
inner_dt.to_csv('bags_inner_dt.csv')

# %% [markdown]
# ## 브랜드별 일회권 평균 값 구하기

# %%
inner_dt.brandnm.value_counts()
# Out:
# Gucci                 47
# Chanel                47
# Louis Vuitton         36
# Fendi                  8
# Saint Laurent          4
# Delvaux                4
# Yves Saint Laurent     3
# Celine                 2
# Valentino              2
# Miu Miu                2
# Hermes                 1
# Prada                  1
# Rimowa                 1
# Balenciaga             1
# Name: brandnm, dtype: int64

# %%
inner_dt.query('brandnm == "Chanel"')
# Out:
#     brandnm                                  goodsnm      USER   reg_date  \
# 37   Chanel               quilted leather clutch bag  a1144959 2021-01-30
# 41   Chanel            zipper detail bucket tote bag  a1144766 2021-01-28
# 42   Chanel            zipper detail bucket tote bag  a1146535 2021-02-16
# 43   Chanel            zipper detail bucket tote bag  a1102098 2020-05-29
# 61   Chanel         quilted chain shoulder bag black   a195790 2020-04-13
# 72   Chanel                     classic clutch black   a157063 2019-11-19
# 73   Chanel                     classic clutch black   a157063 2019-11-19
# 74   Chanel                     classic clutch black   a157063 2019-11-19
# 75   Chanel                     classic clutch black  a1147280 2021-02-23
# 76   Chanel                     classic clutch black  a1147280 2021-02-23
# 77   Chanel                     classic clutch black  a1147280 2021-02-23
# 78   Chanel                     classic clutch black   a145138 2019-10-04
# 79   Chanel                     classic clutch black   a145138 2019-10-04
# 80   Chanel                     classic clutch black   a145138 2019-10-04
# 81   Chanel                     classic clutch black  a1145073 2021-02-01
# 82   Chanel                     classic clutch black  a1145073 2021-02-01
# 83   Chanel                     classic clutch black  a1145073 2021-02-01
# 84   Chanel                     classic clutch black  a1145436 2021-02-04
# 85   Chanel                     classic clutch black  a1145436 2021-02-04
# 86   Chanel                     classic clutch black  a1145436 2021-02-04
# 87   Chanel                     classic clutch black  a1151106 2021-03-28
# 88   Chanel                     classic clutch black  a1151106 2021-03-28
# 89   Chanel                     classic clutch black  a1151106 2021-03-28
# 90   Chanel                     classic clutch black  a1146521 2021-02-15
# 91   Chanel                     classic clutch black  a1146521 2021-02-15
# 92   Chanel                     classic clutch black  a1146521 2021-02-15
# 93   Chanel                     classic clutch black  a1105909 2020-06-24
# 94   Chanel                     classic clutch black  a1105909 2020-06-24
# 95   Chanel                     classic clutch black  a1105909 2020-06-24
# 96   Chanel                     classic clutch black  a1149788 2021-03-17
# 97   Chanel                     classic clutch black  a1149788 2021-03-17
# 98   Chanel                     classic clutch black  a1149788 2021-03-17
# 99   Chanel                     classic clutch black  a1148370 2021-03-06
# 100  Chanel                     classic clutch black  a1148370 2021-03-06
# 101  Chanel                     classic clutch black  a1148370 2021-03-06
# 102  Chanel                     classic clutch black   a192716 2020-04-02
# 103  Chanel                     classic clutch black   a192716 2020-04-02
# 104  Chanel                     classic clutch black   a192716 2020-04-02
# 105  Chanel                     classic clutch black  a1148485 2021-03-07
# 106  Chanel                     classic clutch black  a1148485 2021-03-07
# 107  Chanel                     classic clutch black  a1148485 2021-03-07
# 123  Chanel  matelasse mademoiselle clutch bag black  a1146652 2021-02-17
# 124  Chanel  matelasse mademoiselle clutch bag black  a1150734 2021-03-24
# 125  Chanel  matelasse mademoiselle clutch bag black   a191314 2020-03-28
# 144  Chanel                           Tote beige bag  a1136536 2020-12-11
# 145  Chanel                           Tote beige bag  a1149929 2021-03-18
# 156  Chanel         chevron quilted clutch bag black  a1149790 2021-03-17
#
#     order_date p_type sub_type app_yn  4days  7days
# 37  2021-01-30  7days       BA      Y  49000  59000
# 41  2021-01-28  4days       BA      Y  49000  59000
# 42  2021-02-16  4days       BA      Y  49000  59000
# 43  2021-02-04  4days       BA      Y  49000  59000
# 61  2021-02-24  4days       BA      Y  49000  59000
# 72  2021-02-24  4days       BA      Y  49000  59000
# 73  2021-02-24  4days       BA      Y  39000  49000
# 74  2021-02-24  4days       BA      Y  49000  59000
# 75  2021-02-23  4days       BA      Y  49000  59000
# 76  2021-02-23  4days       BA      Y  39000  49000
# 77  2021-02-23  4days       BA      Y  49000  59000
# 78  2021-02-13  7days       BA      Y  49000  59000
# 79  2021-02-13  7days       BA      Y  39000  49000
# 80  2021-02-13  7days       BA      Y  49000  59000
# 81  2021-02-04  4days       BA      Y  49000  59000
# 82  2021-02-04  4days       BA      Y  39000  49000
# 83  2021-02-04  4days       BA      Y  49000  59000
# 84  2021-02-04  7days       BA      Y  49000  59000
# 85  2021-02-04  7days       BA      Y  39000  49000
# 86  2021-02-04  7days       BA      Y  49000  59000
# 87  2021-03-31  4days       BA      Y  49000  59000
# 88  2021-03-31  4days       BA      Y  39000  49000
# 89  2021-03-31  4days       BA      Y  49000  59000
# 90  2021-03-25  7days       BA      N  49000  59000
# 91  2021-03-25  7days       BA      N  39000  49000
# 92  2021-03-25  7days       BA      N  49000  59000
# 93  2021-03-24  4days       BA      Y  49000  59000
# 94  2021-03-24  4days       BA      Y  39000  49000
# 95  2021-03-24  4days       BA      Y  49000  59000
# 96  2021-03-17  4days       BA      Y  49000  59000
# 97  2021-03-17  4days       BA      Y  39000  49000
# 98  2021-03-17  4days       BA      Y  49000  59000
# 99  2021-03-09  7days       BA      Y  49000  59000
# 100 2021-03-09  7days       BA      Y  39000  49000
# 101 2021-03-09  7days       BA      Y  49000  59000
# 102 2021-03-09  4days       BA      Y  49000  59000
# 103 2021-03-09  4days       BA      Y  39000  49000
# 104 2021-03-09  4days       BA      Y  49000  59000
# 105 2021-03-08  7days       BA      Y  49000  59000
# 106 2021-03-08  7days       BA      Y  39000  49000
# 107 2021-03-08  7days       BA      Y  49000  59000
# 123 2021-02-17  7days       BA      Y  39000  49000
# 124 2021-03-25  7days       BA      Y  39000  49000
# 125 2021-03-08  7days       BA      Y  39000  49000
# 144 2021-03-30  7days       BA      Y  49000  59000
# 145 2021-03-19  7days       BA      Y  49000  59000
# 156 2021-03-18  7days       BA      Y  49000  59000

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux
        # colab에서는 runtime을 <꼭> 재시작 해야함.
        # 런타임을 재시작 하지 않고 폰트 설치를 하면 기본 설정 폰트가 로드되어 한글이 깨짐.
        # !apt-get update -qq
        # !apt-get install fonts-nanum -qq  > /dev/null

        import matplotlib.font_manager as fm

        fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
        font = fm.FontProperties(fname=fontpath, size=9)
        fm._rebuild()
        font_family = "NanumBarunGothic"
    return font_family

# %%
# 시각화를 위한 폰트설정
# 위에서 만든 함수를 통해 시스템 폰트를 불러와서 font_family 라는 변수에 할당.
a = get_font_family()
# 폰트설정
import matplotlib.pyplot as plt 
plt.rc("font", family = a)
# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)
# ggplot으로 그래프 스타일 설정 / 개인 자유
plt.style.use("ggplot")

import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

#한글 폰트 설정
plt.rcParams['font.family'] = 'HYGothic-Extra'

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(x='brandnm', y='4days', data=inner_dt)
plt.xticks(rotation=-90)

plt.subplot(122)
plt.scatter(x='brandnm', y='7days', data=inner_dt)
plt.xticks(rotation=-90)
plt.show()

# %% [markdown]
# - 일반적으로 7일권이 4일권보다 1만원 정도 비쌈

# %%
brands_mean = inner_dt.groupby('brandnm').mean()
brands_mean.reset_index(inplace=True)
brands_mean
# Out:
#                brandnm         4days         7days
# 0           Balenciaga  49000.000000  59000.000000
# 1               Celine  41500.000000  51500.000000
# 2               Chanel  45808.510638  55808.510638
# 3              Delvaux  59000.000000  69000.000000
# 4                Fendi  46500.000000  56500.000000
# 5                Gucci  46446.808511  56446.808511
# 6               Hermes  39000.000000  49000.000000
# 7        Louis Vuitton  45944.444444  55944.444444
# 8              Miu Miu  39000.000000  49000.000000
# 9                Prada  49000.000000  59000.000000
# 10              Rimowa  39000.000000  49000.000000
# 11       Saint Laurent  49000.000000  59000.000000
# 12           Valentino  39000.000000  49000.000000
# 13  Yves Saint Laurent  49000.000000  59000.000000

# %% [markdown]
# # 데이터 합치기

# %%
#concat
concat_dt = pd.concat([cs_dt,inner_dt], axis=0)
concat_dt
# Out:
#                  brandnm                                    goodsnm      USER  \
# 0                  Gucci         flower dionysus shoulder bag beige   a161237
# 1    El estilo de Claire                 beads cropped jacket black  a1140859
# 2                  Danha  embroidery point oriental mini skirt blue  a1140859
# 3                  Danha                  graphics pattern top pink  a1140859
# 4        Burberry London     buckle basic pattern zipup-jumper navy  a1140740
# ..                   ...                                        ...       ...
# 154               Hermes             fabric fourre tout MM tote bag   a197203
# 155        Louis Vuitton                 studded shoulder bag black  a1123025
# 156               Chanel           chevron quilted clutch bag black  a1149790
# 157                Gucci                    monogram backpack brown  a1149535
# 158                Gucci             GG soho chain clutch bag black  a1147854
#
#       reg_date order_date p_type sub_type app_yn    4days    7days
# 0   2019-12-06 2021-01-15  7days       BA      Y      NaN      NaN
# 1   2021-01-02 2021-01-15  4days        O    NaN      NaN      NaN
# 2   2021-01-02 2021-01-15  4days        B    NaN      NaN      NaN
# 3   2021-01-02 2021-01-15  4days        T    NaN      NaN      NaN
# 4   2021-01-01 2021-01-15  7days        O      Y      NaN      NaN
# ..         ...        ...    ...      ...    ...      ...      ...
# 154 2020-04-19 2021-03-18  7days       BA      N  39000.0  49000.0
# 155 2020-10-07 2021-03-18  7days       BA      Y  39000.0  49000.0
# 156 2021-03-17 2021-03-18  7days       BA      Y  49000.0  59000.0
# 157 2021-03-16 2021-03-16  7days       BA      N  49000.0  59000.0
# 158 2021-02-28 2021-03-09  4days       BA      Y  49000.0  59000.0
#
# [1630 rows x 10 columns]

# %%
concat_dt.query('sub_type == "BA"').isnull().sum()
# Out:
# brandnm         0
# goodsnm         0
# USER            0
# reg_date        5
# order_date      0
# p_type          0
# sub_type        0
# app_yn         62
# 4days         692
# 7days         692
# dtype: int64

# %%
# 중복 제거 keep = last

concat_dt = concat_dt.drop_duplicates(subset=['brandnm','goodsnm','USER','reg_date',
                                  'order_date', 'p_type', 'sub_type', 'app_yn'], keep='last')

# %%
concat_dt
# Out:
#                  brandnm                                    goodsnm      USER  \
# 0                  Gucci         flower dionysus shoulder bag beige   a161237
# 1    El estilo de Claire                 beads cropped jacket black  a1140859
# 2                  Danha  embroidery point oriental mini skirt blue  a1140859
# 3                  Danha                  graphics pattern top pink  a1140859
# 4        Burberry London     buckle basic pattern zipup-jumper navy  a1140740
# ..                   ...                                        ...       ...
# 154               Hermes             fabric fourre tout MM tote bag   a197203
# 155        Louis Vuitton                 studded shoulder bag black  a1123025
# 156               Chanel           chevron quilted clutch bag black  a1149790
# 157                Gucci                    monogram backpack brown  a1149535
# 158                Gucci             GG soho chain clutch bag black  a1147854
#
#       reg_date order_date p_type sub_type app_yn    4days    7days
# 0   2019-12-06 2021-01-15  7days       BA      Y      NaN      NaN
# 1   2021-01-02 2021-01-15  4days        O    NaN      NaN      NaN
# 2   2021-01-02 2021-01-15  4days        B    NaN      NaN      NaN
# 3   2021-01-02 2021-01-15  4days        T    NaN      NaN      NaN
# 4   2021-01-01 2021-01-15  7days        O      Y      NaN      NaN
# ..         ...        ...    ...      ...    ...      ...      ...
# 154 2020-04-19 2021-03-18  7days       BA      N  39000.0  49000.0
# 155 2020-10-07 2021-03-18  7days       BA      Y  39000.0  49000.0
# 156 2021-03-17 2021-03-18  7days       BA      Y  49000.0  59000.0
# 157 2021-03-16 2021-03-16  7days       BA      N  49000.0  59000.0
# 158 2021-02-28 2021-03-09  4days       BA      Y  49000.0  59000.0
#
# [1478 rows x 10 columns]

# %%
concat_dt.query('sub_type == "BA"').isnull().sum()
# Out:
# brandnm         0
# goodsnm         0
# USER            0
# reg_date        5
# order_date      0
# p_type          0
# sub_type        0
# app_yn         62
# 4days         574
# 7days         574
# dtype: int64

# %%
a = concat_dt.query('sub_type == "BA"')
print(a.brandnm.nunique()) # 47개 브랜드
print(a.brandnm.unique())
# Out:
# 47
# ['Gucci' 'Louis Vuitton' 'Tory Burch' 'Chloe' 'Prada' 'Fendi' 'Dior'
#  'Bottega Veneta' 'Saint Laurent' 'Celine' 'Christian Dior'
#  'Biker Starlet' 'Givenchy' 'Chanel' 'Salvatore Ferragamo'
#  'Vivienne Westwood' 'Yves Saint Laurent' 'Burberry' 'Vunque' 'Balenciaga'
#  'Miu Miu' 'Mulberry' 'Marni' 'Dolce & Gabbana' 'DELLEST' 'Play Nomore'
#  'Valentino' 'Rimowa' 'Rosa.K' 'Bulgari' 'A.P.C.' 'Kenzo'
#  'Cesare Paciotti' 'Stella Mccartney' 'Goyard' 'Maison Margiela' 'Coach'
#  'thom browne' 'BYREDO' 'Rebecca Minkoff' 'Hermes' 'Furla' 'Delvaux'
#  'Red Valentino' 'Rogervivier' 'Off White' 'Clu']

# %%
concat_dt.duplicated().sum()
# Out:
# 0

# %%
an = concat_dt.app_yn.fillna('N')
concat_dt['app_yn'] = an
concat_dt
# Out:
#                  brandnm                                    goodsnm      USER  \
# 0                  Gucci         flower dionysus shoulder bag beige   a161237
# 1    El estilo de Claire                 beads cropped jacket black  a1140859
# 2                  Danha  embroidery point oriental mini skirt blue  a1140859
# 3                  Danha                  graphics pattern top pink  a1140859
# 4        Burberry London     buckle basic pattern zipup-jumper navy  a1140740
# ..                   ...                                        ...       ...
# 154               Hermes             fabric fourre tout MM tote bag   a197203
# 155        Louis Vuitton                 studded shoulder bag black  a1123025
# 156               Chanel           chevron quilted clutch bag black  a1149790
# 157                Gucci                    monogram backpack brown  a1149535
# 158                Gucci             GG soho chain clutch bag black  a1147854
#
#       reg_date order_date p_type sub_type app_yn    4days    7days
# 0   2019-12-06 2021-01-15  7days       BA      Y      NaN      NaN
# 1   2021-01-02 2021-01-15  4days        O      N      NaN      NaN
# 2   2021-01-02 2021-01-15  4days        B      N      NaN      NaN
# 3   2021-01-02 2021-01-15  4days        T      N      NaN      NaN
# 4   2021-01-01 2021-01-15  7days        O      Y      NaN      NaN
# ..         ...        ...    ...      ...    ...      ...      ...
# 154 2020-04-19 2021-03-18  7days       BA      N  39000.0  49000.0
# 155 2020-10-07 2021-03-18  7days       BA      Y  39000.0  49000.0
# 156 2021-03-17 2021-03-18  7days       BA      Y  49000.0  59000.0
# 157 2021-03-16 2021-03-16  7days       BA      N  49000.0  59000.0
# 158 2021-02-28 2021-03-09  4days       BA      Y  49000.0  59000.0
#
# [1478 rows x 10 columns]

# %%
concat_dt.reset_index(inplace=True)
concat_dt.drop('index', axis=1, inplace=True)

# %%
zero4 = concat_dt['4days'].fillna(0) # 결측치를 0으로 채움
concat_dt['4days'] = zero4

zero7 = concat_dt['7days'].fillna(0) # 결측치를 0으로 채움
concat_dt['7days'] = zero7

# %%
concat_dt
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1473               Hermes             fabric fourre tout MM tote bag
# 1474        Louis Vuitton                 studded shoulder bag black
# 1475               Chanel           chevron quilted clutch bag black
# 1476                Gucci                    monogram backpack brown
# 1477                Gucci             GG soho chain clutch bag black
#
#           USER   reg_date order_date p_type sub_type app_yn    4days    7days
# 0      a161237 2019-12-06 2021-01-15  7days       BA      Y      0.0      0.0
# 1     a1140859 2021-01-02 2021-01-15  4days        O      N      0.0      0.0
# 2     a1140859 2021-01-02 2021-01-15  4days        B      N      0.0      0.0
# 3     a1140859 2021-01-02 2021-01-15  4days        T      N      0.0      0.0
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y      0.0      0.0
# ...        ...        ...        ...    ...      ...    ...      ...      ...
# 1473   a197203 2020-04-19 2021-03-18  7days       BA      N  39000.0  49000.0
# 1474  a1123025 2020-10-07 2021-03-18  7days       BA      Y  39000.0  49000.0
# 1475  a1149790 2021-03-17 2021-03-18  7days       BA      Y  49000.0  59000.0
# 1476  a1149535 2021-03-16 2021-03-16  7days       BA      N  49000.0  59000.0
# 1477  a1147854 2021-02-28 2021-03-09  4days       BA      Y  49000.0  59000.0
#
# [1478 rows x 10 columns]

# %%
concat_dt.isnull().sum()
# Out:
# brandnm       29
# goodsnm        0
# USER           0
# reg_date       6
# order_date     0
# p_type         0
# sub_type       0
# app_yn         0
# 4days          0
# 7days          0
# dtype: int64

# %%
#concat_dt[concat_dt['brandnm'].isnull()] # TP라서 상관 x

# %%
concat_dt.isnull().sum()
# Out:
# brandnm       29
# goodsnm        0
# USER           0
# reg_date       6
# order_date     0
# p_type         0
# sub_type       0
# app_yn         0
# 4days          0
# 7days          0
# dtype: int64

# %%
concat_dt[concat_dt['brandnm'].isnull()] # sub_type이 TP
# Out:
#      brandnm                                            goodsnm      USER  \
# 138      NaN  feminine military blouse & high waist wide slacks  a1144948
# 139      NaN  button basic pattern doublebreasted-jacket sky...   a170041
# 151      NaN  lace point shirring blouse pink & lace detail ...  a1141009
# 209      NaN  printing pattern hoodie grey & pocket basic pa...  a1144470
# 252      NaN  button basic pattern jacket black & pocket bas...   a121913
# 265      NaN      buckle shirt & embroidery lace skirt charcoal  a1132297
# 268      NaN  button tweed pattern doublebreasted-coat multi...  a1127979
# 310      NaN  long sleeve rib t-shirt & check pattern square...  a1134915
# 323      NaN         cutout neck knit & color pleats belt skirt  a1141257
# 346      NaN  El estilo de Claire - neoprene botanical print...  a1107090
# 351      NaN              frill detail knit & dot pattern skirt   a171081
# 416      NaN  stripe boat neck t-shirt & buckle suspender dress  a1147458
# 472      NaN  stripe pattern long vest gray & wrap detail st...  a1145316
# 492      NaN       no collar simple jacket& crease slacks ivory  a1146852
# 493      NaN  button check pattern jacket yellow & pocket ch...  a1146852
# 510      NaN                waffle bulky knit & wool slim skirt  a1146854
# 709      NaN  [66]El estilo de Claire - wang letter neoprene...  a1139388
# 710      NaN           embroidery twist knit & mini gored skirt  a1139388
# 812      NaN  ribbon flower pattern blouse black & pleats fl...  a1149885
# 824      NaN               color lace blouse & color lace skirt   a110947
# 860      NaN     shoulder button pullover & burnout flare skirt  a1150959
# 874      NaN  cut out detail button pointed top & stripe pat...  a1150675
# 883      NaN  button stripe pattern wool jacket black & pock...  a1124921
# 911      NaN  embossing detail crop jacket & pleats detail p...   a174425
# 975      NaN  lettering pattern top mint & pocket basic patt...  a1150312
# 1062     NaN  button basic pattern cardigan pink & basic pat...  a1147111
# 1109     NaN    lace pattern top pink & lace pattern skirt pink  a1149269
# 1269     NaN  button check pattern jacket brown & pocket che...  a1148229
# 1289     NaN  ribbon flower pattern top navy & flower patter...  a1147799
#
#        reg_date order_date p_type sub_type app_yn  4days  7days
# 138  2021-01-30 2021-01-30  4days       TP      Y    0.0    0.0
# 139  2020-01-01 2021-01-30  4days       TP      Y    0.0    0.0
# 151  2021-01-04 2021-01-28  4days       TP      Y    0.0    0.0
# 209  2021-01-25 2021-01-26  4days       TP      Y    0.0    0.0
# 252  2019-05-05 2021-01-21  4days       TP      Y    0.0    0.0
# 265  2020-11-22 2021-01-21  7days       TP      Y    0.0    0.0
# 268  2020-10-31 2021-01-21  7days       TP      Y    0.0    0.0
# 310  2020-12-03 2021-01-19  7days       TP      N    0.0    0.0
# 323  2021-01-05 2021-01-19  4days       TP      Y    0.0    0.0
# 346  2020-07-03 2021-01-17  4days       TP      Y    0.0    0.0
# 351  2020-01-06 2021-01-17  7days       TP      Y    0.0    0.0
# 416  2021-02-24 2021-02-24  7days       TP      Y    0.0    0.0
# 472  2021-02-03 2021-02-22  4days       TP      Y    0.0    0.0
# 492  2021-02-18 2021-02-19  7days       TP      N    0.0    0.0
# 493  2021-02-18 2021-02-19  7days       TP      N    0.0    0.0
# 510  2021-02-18 2021-02-18  7days       TP      Y    0.0    0.0
# 709  2020-12-23 2021-02-04  4days       TP      Y    0.0    0.0
# 710  2020-12-23 2021-02-04  4days       TP      Y    0.0    0.0
# 812  2021-03-18 2021-03-30  4days       TP      Y    0.0    0.0
# 824  2018-11-01 2021-03-29  7days       TP      Y    0.0    0.0
# 860  2021-03-26 2021-03-26  4days       TP      N    0.0    0.0
# 874  2021-03-24 2021-03-26  7days       TP      Y    0.0    0.0
# 883  2020-10-17 2021-03-25  4days       TP      Y    0.0    0.0
# 911  2020-01-16 2021-03-24  4days       TP      Y    0.0    0.0
# 975  2021-03-22 2021-03-22  4days       TP      Y    0.0    0.0
# 1062 2021-02-21 2021-03-17  4days       TP      Y    0.0    0.0
# 1109 2021-03-14 2021-03-16  4days       TP      N    0.0    0.0
# 1269 2021-03-04 2021-03-04  4days       TP      N    0.0    0.0
# 1289 2021-02-28 2021-03-03  7days       TP      Y    0.0    0.0

# %% [markdown]
# ### 나머지 33개 브랜드 값은??

# %%
excepted = concat_dt.loc[(concat_dt['4days'] == 0) & (concat_dt['sub_type'] == "BA")]
excepted
# Out:
#                  brandnm                                   goodsnm      USER  \
# 0                  Gucci        flower dionysus shoulder bag beige   a161237
# 8                  Gucci                        dionysus cross bag  a1143028
# 10         Louis Vuitton  twist monogram patent shoulder bag black  a1140216
# 11            Tory Burch     flower ethnic pattern cross bag white  a1141255
# 14                 Chloe                      faye small bag black  a1129386
# ...                  ...                                       ...       ...
# 1340               Gucci           microssima emily mini bag black  a1147942
# 1341              Chanel                   boy chanel clutch black  a1147960
# 1345            Burberry            check mackenzie cross bag pink  a1147938
# 1348  Yves Saint Laurent                logo point clutch bag pink   a119721
# 1349               Prada                       saffiano lux M gray  a1146069
#
#        reg_date order_date p_type sub_type app_yn  4days  7days
# 0    2019-12-06 2021-01-15  7days       BA      Y    0.0    0.0
# 8    2021-01-14 2021-01-15  4days       BA      Y    0.0    0.0
# 10   2020-12-28 2021-01-15  7days       BA      Y    0.0    0.0
# 11   2021-01-05 2021-01-15  4days       BA      Y    0.0    0.0
# 14   2020-11-09 2021-01-15  4days       BA      Y    0.0    0.0
# ...         ...        ...    ...      ...    ...    ...    ...
# 1340 2021-03-01 2021-03-01  7days       BA      Y    0.0    0.0
# 1341 2021-03-01 2021-03-01  7days       BA      Y    0.0    0.0
# 1345 2021-03-01 2021-03-01  7days       BA      Y    0.0    0.0
# 1348 2019-04-10 2021-03-01  7days       BA      Y    0.0    0.0
# 1349 2021-02-11 2021-03-01  7days       BA      Y    0.0    0.0
#
# [574 rows x 10 columns]

# %%
excepted.brandnm.unique()
# Out:
# array(['Gucci', 'Louis Vuitton', 'Tory Burch', 'Chloe', 'Prada', 'Fendi',
#        'Dior', 'Bottega Veneta', 'Saint Laurent', 'Celine',
#        'Christian Dior', 'Biker Starlet', 'Givenchy', 'Chanel',
#        'Salvatore Ferragamo', 'Vivienne Westwood', 'Yves Saint Laurent',
#        'Burberry', 'Vunque', 'Balenciaga', 'Miu Miu', 'Mulberry', 'Marni',
#        'Dolce & Gabbana', 'DELLEST', 'Play Nomore', 'Valentino', 'Rimowa',
#        'Rosa.K', 'Bulgari', 'A.P.C.', 'Kenzo', 'Cesare Paciotti',
#        'Stella Mccartney', 'Goyard', 'Maison Margiela', 'Coach',
#        'thom browne', 'BYREDO', 'Rebecca Minkoff', 'Hermes', 'Furla',
#        'Delvaux', 'Red Valentino', 'Rogervivier', 'Off White', 'Clu'],
#       dtype=object)

# %%
excepted.brandnm.nunique()
# Out:
# 47

# %%
dt_brands = dt.groupby('brandnm').mean() #크롤링한 데이터를 바탕으로 한 평균 값
dt_brands.reset_index(inplace=True)
#dt_brands.drop('index', axis=1, inplace=True)
dt_brands
# Out:
#                 brandnm         4days         7days
# 0            BALENCIAGA  44000.000000  54000.000000
# 1                CELINE  46000.000000  56000.000000
# 2                CHANEL  47461.538462  57461.538462
# 3               DELVAUX  52333.333333  62333.333333
# 4                 FENDI  46692.307692  56692.307692
# 5               FONTANA  39000.000000  49000.000000
# 6                 GUCCI  46317.073171  56317.073171
# 7                HERMES  39000.000000  49000.000000
# 8         LOUIS VUITTON  45785.714286  55785.714286
# 9               MIU MIU  39000.000000  49000.000000
# 10                PRADA  39000.000000  49000.000000
# 11               RIMOWA  39000.000000  49000.000000
# 12        SAINT LAURENT  43000.000000  53000.000000
# 13  SALVATORE FERRAGAMO  39000.000000  49000.000000
# 14          TRAVEL MATE  34000.000000  44000.000000
# 15            VALENTINO  39000.000000  49000.000000
# 16   YVES SAINT LAURENT  46500.000000  56500.000000

# %%
# brands_mean = inner_dt.groupby('brandnm').mean()
# brands_mean.reset_index(inplace=True)

brands_mean
# Out:
#                brandnm         4days         7days
# 0           Balenciaga  49000.000000  59000.000000
# 1               Celine  41500.000000  51500.000000
# 2               Chanel  45808.510638  55808.510638
# 3              Delvaux  59000.000000  69000.000000
# 4                Fendi  46500.000000  56500.000000
# 5                Gucci  46446.808511  56446.808511
# 6               Hermes  39000.000000  49000.000000
# 7        Louis Vuitton  45944.444444  55944.444444
# 8              Miu Miu  39000.000000  49000.000000
# 9                Prada  49000.000000  59000.000000
# 10              Rimowa  39000.000000  49000.000000
# 11       Saint Laurent  49000.000000  59000.000000
# 12           Valentino  39000.000000  49000.000000
# 13  Yves Saint Laurent  49000.000000  59000.000000

# %%
brands_means = pd.concat([dt_brands, brands_mean], axis=1)
# dt_brands는 크롤링한 데이터의 평균값
# brands_mean은 inner join한 데이터의 평균값
brands_means
# Out:
#                 brandnm         4days         7days             brandnm  \
# 0            BALENCIAGA  44000.000000  54000.000000          Balenciaga
# 1                CELINE  46000.000000  56000.000000              Celine
# 2                CHANEL  47461.538462  57461.538462              Chanel
# 3               DELVAUX  52333.333333  62333.333333             Delvaux
# 4                 FENDI  46692.307692  56692.307692               Fendi
# 5               FONTANA  39000.000000  49000.000000               Gucci
# 6                 GUCCI  46317.073171  56317.073171              Hermes
# 7                HERMES  39000.000000  49000.000000       Louis Vuitton
# 8         LOUIS VUITTON  45785.714286  55785.714286             Miu Miu
# 9               MIU MIU  39000.000000  49000.000000               Prada
# 10                PRADA  39000.000000  49000.000000              Rimowa
# 11               RIMOWA  39000.000000  49000.000000       Saint Laurent
# 12        SAINT LAURENT  43000.000000  53000.000000           Valentino
# 13  SALVATORE FERRAGAMO  39000.000000  49000.000000  Yves Saint Laurent
# 14          TRAVEL MATE  34000.000000  44000.000000                 NaN
# 15            VALENTINO  39000.000000  49000.000000                 NaN
# 16   YVES SAINT LAURENT  46500.000000  56500.000000                 NaN
#
#            4days         7days
# 0   49000.000000  59000.000000
# 1   41500.000000  51500.000000
# 2   45808.510638  55808.510638
# 3   59000.000000  69000.000000
# 4   46500.000000  56500.000000
# 5   46446.808511  56446.808511
# 6   39000.000000  49000.000000
# 7   45944.444444  55944.444444
# 8   39000.000000  49000.000000
# 9   49000.000000  59000.000000
# 10  39000.000000  49000.000000
# 11  49000.000000  59000.000000
# 12  39000.000000  49000.000000
# 13  49000.000000  59000.000000
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN

# %% [markdown]
# - brands_mean에 없는 데이터를 dt_brands에서 가져옴
#     - FONTANA,SALVATORE FERRAGAMO, TRAVEL MATE <- 근데 얘네는 concat_data에 없음

# %%
## 평균 값을 4/7days nan 값에 넣기

for i in range(len(concat_dt)):
    if (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Balenciaga'):
        concat_dt['4days'][i] = 49000
        concat_dt['7days'][i] = 59000
        
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Celine'):
        concat_dt['4days'][i] = 41500
        concat_dt['7days'][i] = 51500

    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Chanel'):
        concat_dt['4days'][i] = 45800
        concat_dt['7days'][i] = 55800

    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Delvaux'):
        concat_dt['4days'][i] = 59000
        concat_dt['7days'][i] = 69000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Fendi'):
        concat_dt['4days'][i] = 46500
        concat_dt['7days'][i] = 56500
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Gucci'):
        concat_dt['4days'][i] = 46450
        concat_dt['7days'][i] = 56450
        
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Hermes'):
        concat_dt['4days'][i] = 39000
        concat_dt['7days'][i] = 49000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Louis Vuitton'):
        concat_dt['4days'][i] = 45950
        concat_dt['7days'][i] = 55950
        
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Miu Miu'):
        concat_dt['4days'][i] = 39000
        concat_dt['7days'][i] = 49000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Prada'):
        concat_dt['4days'][i] = 49000
        concat_dt['7days'][i] = 59000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Rimowa'):
        concat_dt['4days'][i] = 39000
        concat_dt['7days'][i] = 49000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Saint Laurent'):
        concat_dt['4days'][i] = 49000
        concat_dt['7days'][i] = 59000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Valentino'):
        concat_dt['4days'][i] = 39000
        concat_dt['7days'][i] = 49000
    
    elif (concat_dt['sub_type'][i] == 'BA' and concat_dt['brandnm'][i] == 'Yves Saint Laurent'):
        concat_dt['4days'][i] = 49000
        concat_dt['7days'][i] = 59000

    
concat_dt.query('sub_type == "BA"')
# Out:
#             brandnm                                   goodsnm      USER  \
# 0             Gucci        flower dionysus shoulder bag beige   a161237
# 8             Gucci                        dionysus cross bag  a1143028
# 10    Louis Vuitton  twist monogram patent shoulder bag black  a1140216
# 11       Tory Burch     flower ethnic pattern cross bag white  a1141255
# 14            Chloe                      faye small bag black  a1129386
# ...             ...                                       ...       ...
# 1473         Hermes            fabric fourre tout MM tote bag   a197203
# 1474  Louis Vuitton                studded shoulder bag black  a1123025
# 1475         Chanel          chevron quilted clutch bag black  a1149790
# 1476          Gucci                   monogram backpack brown  a1149535
# 1477          Gucci            GG soho chain clutch bag black  a1147854
#
#        reg_date order_date p_type sub_type app_yn    4days    7days
# 0    2019-12-06 2021-01-15  7days       BA      Y  46450.0  56450.0
# 8    2021-01-14 2021-01-15  4days       BA      Y  46450.0  56450.0
# 10   2020-12-28 2021-01-15  7days       BA      Y  45950.0  55950.0
# 11   2021-01-05 2021-01-15  4days       BA      Y      0.0      0.0
# 14   2020-11-09 2021-01-15  4days       BA      Y      0.0      0.0
# ...         ...        ...    ...      ...    ...      ...      ...
# 1473 2020-04-19 2021-03-18  7days       BA      N  39000.0  49000.0
# 1474 2020-10-07 2021-03-18  7days       BA      Y  45950.0  55950.0
# 1475 2021-03-17 2021-03-18  7days       BA      Y  45800.0  55800.0
# 1476 2021-03-16 2021-03-16  7days       BA      N  46450.0  56450.0
# 1477 2021-02-28 2021-03-09  4days       BA      Y  46450.0  56450.0
#
# [699 rows x 10 columns]

# %%
excepted.brandnm.unique()
# Out:
# array(['Gucci', 'Louis Vuitton', 'Tory Burch', 'Chloe', 'Prada', 'Fendi',
#        'Dior', 'Bottega Veneta', 'Saint Laurent', 'Celine',
#        'Christian Dior', 'Biker Starlet', 'Givenchy', 'Chanel',
#        'Salvatore Ferragamo', 'Vivienne Westwood', 'Yves Saint Laurent',
#        'Burberry', 'Vunque', 'Balenciaga', 'Miu Miu', 'Mulberry', 'Marni',
#        'Dolce & Gabbana', 'DELLEST', 'Play Nomore', 'Valentino', 'Rimowa',
#        'Rosa.K', 'Bulgari', 'A.P.C.', 'Kenzo', 'Cesare Paciotti',
#        'Stella Mccartney', 'Goyard', 'Maison Margiela', 'Coach',
#        'thom browne', 'BYREDO', 'Rebecca Minkoff', 'Hermes', 'Furla',
#        'Delvaux', 'Red Valentino', 'Rogervivier', 'Off White', 'Clu'],
#       dtype=object)

# %%
excepted.brandnm.nunique()
# Out:
# 47

# %% [markdown]
# ## 33개 브랜드 크롤링?

# %%
### 검색 리스트 생성

import numpy as np

search_list = excepted['brandnm'].unique()
s_df = pd.DataFrame(search_list)
s_df.columns = ['keyword']

search = list(np.array(s_df['keyword'].tolist()))

search
# Out:
# ['Gucci',
#  'Louis Vuitton',
#  'Tory Burch',
#  'Chloe',
#  'Prada',
#  'Fendi',
#  'Dior',
#  'Bottega Veneta',
#  'Saint Laurent',
#  'Celine',
#  'Christian Dior',
#  'Biker Starlet',
#  'Givenchy',
#  'Chanel',
#  'Salvatore Ferragamo',
#  'Vivienne Westwood',
#  'Yves Saint Laurent',
#  'Burberry',
#  'Vunque',
#  'Balenciaga',
#  'Miu Miu',
#  'Mulberry',
#  'Marni',
#  'Dolce & Gabbana',
#  'DELLEST',
#  'Play Nomore',
#  'Valentino',
#  'Rimowa',
#  'Rosa.K',
#  'Bulgari',
#  'A.P.C.',
#  'Kenzo',
#  'Cesare Paciotti',
#  'Stella Mccartney',
#  'Goyard',
#  'Maison Margiela',
#  'Coach',
#  'thom browne',
#  'BYREDO',
#  'Rebecca Minkoff',
#  'Hermes',
#  'Furla',
#  'Delvaux',
#  'Red Valentino',
#  'Rogervivier',
#  'Off White',
#  'Clu']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys # 엔터키 입력용

import pandas as pd
import time

# %%
# 드라이버
driver = webdriver.Chrome('C:/Temp/chromedriver') # 웹드라이버 객체 생성

# 구글을 열어서 키워드 입력 후 이동
driver.get('https://www.closetshare.com/theclozet/main/index') # 구글 홈페이지 내용 렌더링
time.sleep(1)

# 리스트 선언
clothes_price_list_4 = []
clothes_price_list_7 = []
brandnm_list = []
goodsnm_list = []


# popup 제거
popup = driver.find_element_by_css_selector("[id = 'notshow']")
popup.click()
time.sleep(1)

# 로그인 페이지 이동
login = driver.find_element_by_css_selector("[id = 'account_login']")
login.click()
time.sleep(1)

# 로그인_이메일
login_2 = driver.find_element_by_css_selector('#loginForm > ul > li.ic-email.ic-login-email > a > span')
login_2.click()

# 아이디
email = driver.find_element_by_css_selector("[id = 'email']")
email.send_keys('tmxjel6279@naver.com') # 개인 아이디 입력

# 패스워드
password = driver.find_element_by_css_selector("[id = 'passwd']")
password.send_keys('dkdkdk!0218') # 개인 패스워드 입력

# 로그인 엔터
password.send_keys(Keys.ENTER)

# 렌더링 1초 기다리자
time.sleep(2)

# 가방 카테고리 클릭
bags = driver.find_element_by_css_selector('#cshrHeaderWeb > nav > ul > li:nth-child(2) > a')
bags.click()
time.sleep(2)

# 필터링
filtering = driver.find_element_by_css_selector('#days_flag')
filtering.click()
time.sleep(1)

# 대여가능만 클릭
driver.find_element_by_css_selector('[data ="clist_filter_s1"]').click()


count = 0
# 크롤링을 진행해봅시다

for i in range(5):
    # 검색창에 값 입력f
    driver.find_element_by_xpath('//*[@id="frmList"]/section/section[1]/div[1]/article[1]/input').send_keys(search[i]) # 검색어 입력
    driver.find_element_by_xpath('//*[@id="goodsnmSesrch"]').click() # 검색 버튼 클릭
    time.sleep(1)
    
    for clothes_num in range(1,37) :
        try : 
            # 브랜드명 수집 코드 입니다.
            brandnm = driver.find_element_by_css_selector("#prod_list_item > a:nth-child("+str(clothes_num)+") > span > span.brand")
            brandnm_list.append(brandnm.text)
            print("브랜드 :",brandnm.text)

            # 아이템명 수집 코드입니다.
            goodsnm = driver.find_element_by_css_selector('#prod_list_item > a:nth-child('+str(clothes_num)+') > span > span.cont')
            goodsnm_list.append(goodsnm.text)
            print("아이템 :",goodsnm.text)


            # 한 페이지 내 36개의 아이템을 indexing하여 클릭하기 위한 코드입니다.
            clothes_index = driver.find_element_by_css_selector('#prod_list_item > a:nth-child('+str(clothes_num)+') > span > span.status.noto_m')
            clothes_index.click()
            time.sleep(2)

            # 4일권 / 7일권 수집
            # 가끔가다 보면 대여가 불가능한 제품들은 4일권과 7일권에 대한 가격 정보가 없습니다.
            # 때문에 try, except 구문으로 가격이 없는 것은 0으로 대체합니다.
            try : 
                price = driver.find_element_by_css_selector('#goodsValue_daily')
                clothes_price_list_4.append(price.text.split('\n')[0][5:11])
                clothes_price_list_7.append(price.text.split('\n')[1][5:11])
                print("4일권 :",price.text.split('\n')[0][5:11])
                print("7일권 :",price.text.split('\n')[1][5:11])
            except :
                clothes_price_list_4.append(0)
                clothes_price_list_7.append(0)
                print("4일권 :",0)
                print("7일권 :",0)

            # 뒤로 돌아가서 다른 아이템 정보를 가져올 준비를 합니다.
            go_home = driver.find_element_by_xpath('//*[@id="cshrHeader"]/h1/a')
            go_home.click()
            time.sleep(1)
            
        except :
            pass

        # 전체 아이템 중 몇 번째인지 확인하는 코드입니다.
        count += 1
        print("=====================================", count, "번째")

#     try :
#         # 만일 두 아이템의 이름이 정확하게 일치하지 않으면
#         if items[i] != driver.find_element_by_xpath('//*[@id="prod_list_item"]/a/span/span[3]').text :
#             price_4days.append('not same item')
#             price_7days.append('not same item')
            
#             item_nm = items[i]
#             bag_name.append(item_nm)
            
#             print(bag_name[i])
#             print("4일권 :",price_4days[i])
#             print("7일권 :",price_7days[i])
            
#             # 홈으로 돌아가서
#             go_home = driver.find_element_by_xpath('//*[@id="cshrHeader"]/h1/a')
#             go_home.click()
            
#             # 다시 가방 카테고리 누르기
#             bags = driver.find_element_by_css_selector('#cshrHeaderWeb > nav > ul > li:nth-child(2) > a')
#             bags.click()
#             time.sleep(2)
            

#         else : # 두 아이템의 이름이 같으면
#             # 이거는 검색 결과가 하나만 나올 때 유효함 ㅜㅜ ↓
#             item_nm = driver.find_element_by_xpath('//*[@id="prod_list_item"]/a/span/span[3]').text
#             bag_name.append(item_nm)
        
#             # 이미지 클릭해서 세부 페이지로 들어가기
#             driver.find_element_by_xpath('//*[@id="prod_list_item"]/a[1]/span').click()
#             time.sleep(1)
        
#             # 4일권/7일권 가격 데이터 가져오기
#             try : 
#                 price = driver.find_element_by_css_selector('#goodsValue_daily')
#                 price_4days.append(price.text.split('\n')[0][5:11])
#                 price_7days.append(price.text.split('\n')[1][5:11])
#                 bag_name.append(item_nm)
                
#                 print(bag_name[i])
#                 print("4일권 :",price.text.split('\n')[0][5:11])
#                 print("7일권 :",price.text.split('\n')[1][5:11])
#                 print("--------------------")
                
#             except : # 가격 데이터 없으면
#                 price_4days.append('no')
#                 price_7days.append('no')
#                 bag_name.append(item_nm)
                
#                 print(bag_name[i])
#                 print("4일권 :", price_4days[i])
#                 print("7일권 :", price_7days[i])
#                 print("--------------------")

#             # 뒤로 돌아가서 다른 아이템 정보를 가져올 준비를 합니다.
#             go_home = driver.find_element_by_xpath('//*[@id="cshrHeader"]/h1/a')
#             go_home.click()
            
#             bags = driver.find_element_by_css_selector('#cshrHeaderWeb > nav > ul > li:nth-child(2) > a')
#             bags.click()
        
#     except :
#         #에러나면(검색 결과가 없으면) pass 홈으로 돌아가서
#         price_4days.append('no result')
#         price_7days.append('no result')
#         bag_name.append(item_nm)
        
#         print(bag_name[i])
#         print("4일권 :", price_4days[i])
#         print("7일권 :", price_7days[i])
#         print("--------------------")
        
#         go_home = driver.find_element_by_xpath('//*[@id="cshrHeader"]/h1/a')
#         go_home.click()

#         # 다시 가방 카테고리 누르기
#         bags = driver.find_element_by_css_selector('#cshrHeaderWeb > nav > ul > li:nth-child(2) > a')
#         bags.click()
#         time.sleep(2)
# Out:
# 브랜드 : GUCCI
# 아이템 : flower pattern clutch bag
# 4일권 : 49,000
# 7일권 : 59,000
# ===================================== 1 번째
# ===================================== 2 번째
# ===================================== 3 번째
# ===================================== 4 번째
# ===================================== 5 번째
# ===================================== 6 번째
# ===================================== 7 번째
# ===================================== 8 번째
# ===================================== 9 번째
# ===================================== 10 번째
# ===================================== 11 번째
# ===================================== 12 번째
# ===================================== 13 번째
# ===================================== 14 번째
# ===================================== 15 번째
# ===================================== 16 번째
# ===================================== 17 번째
# ===================================== 18 번째
# ===================================== 19 번째
# ===================================== 20 번째
# ===================================== 21 번째
# ===================================== 22 번째
# ===================================== 23 번째
# ===================================== 24 번째
# ===================================== 25 번째
# ===================================== 26 번째
# ===================================== 27 번째
# ===================================== 28 번째
# ===================================== 29 번째
# ===================================== 30 번째
# ===================================== 31 번째
# ===================================== 32 번째
# ===================================== 33 번째
# ===================================== 34 번째
# ===================================== 35 번째
# ===================================== 36 번째
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-41-253ca55e7440> in <module>
#      60 for i in range(5):
#      61     # 검색창에 값 입력f
# ---> 62     driver.find_element_by_xpath('//*[@id="frmList"]/section/section[1]/div[1]/article[1]/input').send_keys(search[i]) # 검색어 입력
#      63     driver.find_element_by_xpath('//*[@id="goodsnmSesrch"]').click() # 검색 버튼 클릭
#      64     time.sleep(1)
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="frmList"]/section/section[1]/div[1]/article[1]/input"}
#   (Session info: chrome=90.0.4430.212)

# %% [markdown]
# ## cs_dt에서 가방만

# %%
bags = cs_dt.query('sub_type == "BA"').reset_index()
bags.drop('index', axis=1, inplace=True)
bags# 692 rows

# %% [markdown]
# ### bags와 dt merge

# %%
bag_merge = pd.merge(bags, dt, how='left', on='goodsnm')
bag_merge

# %%
an = bag_merge.app_yn.fillna('N')
bag_merge['app_yn'] = an
bag_merge

# %%
### 4days와 7days가 NaN인 곳 다른 값으로 채운 후 추출
an = bag_merge['4days'].fillna(0)
an2 = bag_merge['7days'].fillna(0)
bag_merge['4days'] = an
bag_merge['7days'] = an2
bag_merge.drop('brandnm_y', axis=1, inplace=True)
bag_merge

# %%
bag_merge.isnull().sum()

# %%
bag_merge.info()

# %%
# 가격 없는 데이터만 추출

no_price = bag_merge.loc[(bag_merge['4days'] == 0) | (bag_merge['7days'] == 0)]
no_price

# %%
import numpy as np

search_list = no_price['brandnm_x'] + ' ' + no_price['goodsnm'] # Series
s_df = pd.DataFrame(search_list)
s_df.columns = ['keyword']

search = list(np.array(s_df['keyword'].tolist()))

# %%
search # 검색할 리스트

# %%
# 아이템 이름만 따로
item_list = no_price['goodsnm']
i_df = pd.DataFrame(item_list)
i_df.columns = ['items']

items = list(np.array(i_df['items'].tolist()))

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys # 엔터키 입력용

import pandas as pd
import time

# %%
print(search[:5], '\n\n')
print(items[:5])

# %%
print(price_4days)
print(price_7days)
print(bag_name)

# %%
# 리스트들 df로 변환 - 209번까지 수집

bag_test = pd.DataFrame([ x for x in zip(bag_name,price_4days,price_7days)])
bag_test.columns = ['Bag','4days','7days']
bag_test
#bag_test.drop_duplicates()
