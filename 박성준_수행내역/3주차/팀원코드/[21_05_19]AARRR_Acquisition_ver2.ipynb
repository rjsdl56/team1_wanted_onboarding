# %%
import pandas as pd 
import numpy as np 
#시각화
import matplotlib.pyplot as plt
import seaborn as sns
#경고무시
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'HYGothic-Extra'  # (Windows 용) 한글 출력을 위한 글꼴 설정
plt.rcParams['axes.unicode_minus'] = False    # 문자 - (마이너스) 정상 출력을 위한 코드

#plt.rcParams['font.family'] = 'AppleGothic' # 맥(Mac) 사용자

# %%
df_ori = pd.read_csv('./팀_basline_csv.csv', encoding='utf-8')

# %%
df=df_ori.copy()
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1461   Yves Saint Laurent                 logo point clutch bag pink
# 1462                Prada                        saffiano lux M gray
# 1463             Burberry                basic pattern sweater beige
# 1464               Chanel        graphics pattern sweat-shirts white
# 1465             Burberry                  classic trench coat beige
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 0      a161237  2019-12-06  2021-01-15  7days       BA      Y  금요일       주중
# 1     a1140859  2021-01-02  2021-01-15  4days        O      N  금요일       주중
# 2     a1140859  2021-01-02  2021-01-15  4days        B      N  금요일       주중
# 3     a1140859  2021-01-02  2021-01-15  4days        T      N  금요일       주중
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y  금요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1461   a119721  2019-04-10  2021-03-01  7days       BA      Y  공휴일       휴일
# 1462  a1146069  2021-02-11  2021-03-01  7days       BA      Y  공휴일       휴일
# 1463  a1147848  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1464  a1147788  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1465   a190054  2020-03-24  2021-03-01  4days        O      Y  공휴일       휴일
#
#       month  How_long
# 0         1       406
# 1         1        13
# 2         1        13
# 3         1        13
# 4         1        14
# ...     ...       ...
# 1461      3       691
# 1462      3        18
# 1463      3         1
# 1464      3         1
# 1465      3       342
#
# [1466 rows x 12 columns]

# %% [markdown]
# >**(1).brandnm: 아이템의 브랜드 이름 컬럼 : 범주형 <br>
# (2).goodsnm : 아이템의 특성을 담은 이름 컬럼 : 범주형 <br>
# (3). USER : 사용자 ID 컬럼 : 범주형 <br>
# (4). reg_date : 사용자 가입일 컬럼 : 날짜형 <br>
# (5). order_date : 아이템 주문일 컬럼 : 날짜형<br>
# (6). p_type : 주문 상품권 종류 5일 7일 : 범주형<br>
# (7). sub_type : 주문 아이템 카테고리 : 범주형 <br>
# (8). add_yn : 사용자의 어플리케이션 사용 여부 : 범주형**

# %% [markdown]
# # Acquisition

# %% [markdown]
# ## 어떻게 많은 고객을 서비스로 유입시킬 수 있을 것인가?
#
# ### 1. 전체 브랜드 중 선호도가 높은 순위

# %%
# print(df.brandnm.unique())
# print('='*30)
print('클로젯쉐어 전체 브랜드 분류 수 :', len(df.brandnm.unique()))
# Out:
# 클로젯쉐어 전체 브랜드 분류 수 : 245

# %%
df.groupby('brandnm').count()
# Out:
#                  goodsnm  USER  reg_date  order_date  p_type  sub_type  \
# brandnm
# & Other Stories        8     8         8           8       8         8
# A BY A                 1     1         1           1       1         1
# A.P.C.                 3     3         3           3       3         3
# ACNE STUDIOS           4     4         4           4       4         4
# Adidas                 1     1         1           1       1         1
# ...                  ...   ...       ...         ...     ...       ...
# Zooc                   2     2         2           2       2         2
# cecilie bahnsen        1     1         1           1       1         1
# khrisjoy               1     1         1           1       1         1
# roajeu                 1     1         1           1       1         1
# thom browne            1     1         1           1       1         1
#
#                  app_yn  days  day_type  month  How_long
# brandnm
# & Other Stories       8     8         8      8         8
# A BY A                1     1         1      1         1
# A.P.C.                3     3         3      3         3
# ACNE STUDIOS          4     4         4      4         4
# Adidas                1     1         1      1         1
# ...                 ...   ...       ...    ...       ...
# Zooc                  2     2         2      2         2
# cecilie bahnsen       1     1         1      1         1
# khrisjoy              1     1         1      1         1
# roajeu                1     1         1      1         1
# thom browne           1     1         1      1         1
#
# [245 rows x 11 columns]

# %%
# 구매가 많은 상위 10개 브랜드
df.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 230
# Chanel                 90
# Saint Laurent          86
# Louis Vuitton          79
# Prada                  58
# Burberry               53
# Yves Saint Laurent     38
# Thom Browne            33
# Mixed                  29
# Celine                 28
# Name: brandnm, dtype: int64

# %%
plt.rcParams['font.family'] = 'HYGothic-Extra'

best_br = df.brandnm.value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(25,8))
sns.barplot(best_br.index, best_br.values, palette='dark')
plt.grid()
plt.title('상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %%
# 상위 10개 브랜드 sub_type 분포
# br = list(df.brandnm.value_counts().sort_values(ascending=False).head(30))
br = list(df.brandnm.value_counts().sort_values(ascending=False).head(10).index)

f, ax = plt.subplots(5,2 , figsize = (20,30))
axx = ax.flatten()
plt.rcParams['font.family'] = 'HYGothic-Extra'

for axx2, j in zip(axx, br) :
    sns.set_style('whitegrid')
    plt.subplot(axx2)
    b_ca = df[df['brandnm'] == j]
    sns.countplot(data = b_ca, x= 'sub_type', hue='p_type', palette='Accent', ax= axx2)
    plt.title(j, fontsize = 18)

# %% [markdown]
# ### - Top1 : Gucci 데이터만 따로 보기

# %%
# gucci 데이터만 따로 보기
gucci = df.query('brandnm == "Gucci"')[:]
gucci
# Out:
#      brandnm                              goodsnm      USER    reg_date  \
# 0      Gucci   flower dionysus shoulder bag beige   a161237  2019-12-06
# 8      Gucci                   dionysus cross bag  a1143028  2021-01-14
# 16     Gucci  microssima mini cross body bag pink  a1142921  2021-01-14
# 34     Gucci       padlock GG canvas shoulder bag   a143862  2019-09-29
# 36     Gucci                 flap cross bag black  a1141099  2021-01-04
# ...      ...                                  ...       ...         ...
# 1445   Gucci              super mini sylvie white  a1144433  2021-01-25
# 1447   Gucci     vintage web GG two way bag brown  a1117218  2020-08-30
# 1451   Gucci     sylvie mini chain ribbon bag red  a1147961  2021-03-01
# 1452   Gucci      microssima emily mini bag black  a1147942  2021-03-01
# 1454   Gucci  marmont gg logo quilted bag Black 2   a177034  2020-01-23
#
#       order_date p_type sub_type app_yn days day_type  month  How_long
# 0     2021-01-15  7days       BA      Y  금요일       주중      1       406
# 8     2021-01-15  4days       BA      Y  금요일       주중      1         1
# 16    2021-01-14  4days       BA      Y  목요일       주중      1         0
# 34    2021-01-14  4days       BA      Y  목요일       주중      1       473
# 36    2021-01-13  4days       BA      Y  수요일       주중      1         9
# ...          ...    ...      ...    ...  ...      ...    ...       ...
# 1445  2021-03-02  7days       BA      Y  화요일       주중      3        36
# 1447  2021-03-02  7days       BA      Y  화요일       주중      3       184
# 1451  2021-03-01  4days       BA      Y  공휴일       휴일      3         0
# 1452  2021-03-01  7days       BA      Y  공휴일       휴일      3         0
# 1454  2021-03-01  4days       BA      Y  공휴일       휴일      3       403
#
# [230 rows x 12 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.rcParams['font.family'] = 'HYGothic-Extra'


plt.subplot(221)
sns.countplot(data=gucci, x='days')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=gucci, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=gucci, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=gucci, x='days', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Gucci 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top2 : Chanel 데이터만 따로 보기

# %%
Chanel = df.query('brandnm == "Chanel"')[:]
Chanel
# Out:
#      brandnm                                            goodsnm      USER  \
# 28    Chanel  brooch stripe pattern turtle neck turtleneck navy  a1136028
# 58    Chanel            pocket tweed pattern cashmere coat pink  a1138513
# 98    Chanel                   classic chain shoulder bag black  a1141379
# 103   Chanel      pocket basic pattern wool fullzip-jacket grey  a1141288
# 135   Chanel          pocket graphics pattern zipup-jumper navy  a1112031
# ...      ...                                                ...       ...
# 1450  Chanel              stripe pattern pointed cardigan multi  a1147961
# 1453  Chanel                            boy chanel clutch black  a1147960
# 1455  Chanel                  brooch check pattern jacket cream  a1146108
# 1456  Chanel            pocket tweed pattern cashmere coat pink  a1147959
# 1464  Chanel                graphics pattern sweat-shirts white  a1147788
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 28    2020-12-09  2021-01-14  4days        T      Y  목요일       주중      1
# 58    2020-12-20  2021-01-11  4days        O      Y  월요일       주중      1
# 98    2021-01-06  2021-01-06  7days       BA      Y  수요일       주중      1
# 103   2021-01-05  2021-01-06  4days        O      Y  수요일       주중      1
# 135   2020-08-15  2021-01-01  7days        O      N  공휴일       휴일      1
# ...          ...         ...    ...      ...    ...  ...      ...    ...
# 1450  2021-03-01  2021-03-01  4days        O      Y  공휴일       휴일      3
# 1453  2021-03-01  2021-03-01  7days       BA      Y  공휴일       휴일      3
# 1455  2021-02-11  2021-03-01  7days        O      Y  공휴일       휴일      3
# 1456  2021-03-01  2021-03-01  7days        O      N  공휴일       휴일      3
# 1464  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일      3
#
#       How_long
# 28          36
# 58          22
# 98           0
# 103          1
# 135        139
# ...        ...
# 1450         0
# 1453         0
# 1455        18
# 1456         0
# 1464         1
#
# [90 rows x 12 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.rcParams['font.family'] = 'HYGothic-Extra'


plt.subplot(221)
sns.countplot(data=Chanel, x='days')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Chanel, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Chanel, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Chanel, x='days', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Chanel 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top3 : Saint Laurent 데이터만 따로 보기

# %%
S_Laurent = df.query('brandnm == "Saint Laurent"')[:]
S_Laurent
# Out:
#             brandnm                            goodsnm      USER    reg_date  \
# 45    Saint Laurent    chevron quilted cross bag black  a1140871  2021-01-02
# 51    Saint Laurent    chevron quilted cross bag black  a1141925  2021-01-09
# 56    Saint Laurent        mini sunset chain bag black  a1142471  2021-01-12
# 67    Saint Laurent  button basic pattern blazer black  a1140758  2021-01-01
# 115   Saint Laurent      quilted calfskin shoulder bag  a1139320  2020-12-22
# ...             ...                                ...       ...         ...
# 1311  Saint Laurent    chevron quilted cross bag black  a1135400  2020-12-05
# 1320  Saint Laurent  monogram mini universal bag black  a1148747  2021-03-09
# 1357  Saint Laurent    chevron quilted cross bag black  a1148129  2021-03-03
# 1377  Saint Laurent      quilted calfskin shoulder bag  a1148237  2021-03-04
# 1383  Saint Laurent    chevron quilted cross bag black  a1148220  2021-03-04
#
#       order_date p_type sub_type app_yn days day_type  month  How_long
# 45    2021-01-13  4days       BA      Y  수요일       주중      1        11
# 51    2021-01-12  4days       BA      Y  화요일       주중      1         3
# 56    2021-01-12  7days       BA      Y  화요일       주중      1         0
# 67    2021-01-10  7days        O      Y  일요일       휴일      1         9
# 115   2021-01-05  7days       BA      Y  화요일       주중      1        14
# ...          ...    ...      ...    ...  ...      ...    ...       ...
# 1311  2021-03-09  4days       BA      Y  화요일       주중      3        94
# 1320  2021-03-09  7days       BA      Y  화요일       주중      3         0
# 1357  2021-03-06  7days       BA      N  토요일       휴일      3         3
# 1377  2021-03-04  4days       BA      N  목요일       주중      3         0
# 1383  2021-03-04  7days       BA      Y  목요일       주중      3         0
#
# [86 rows x 12 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.rcParams['font.family'] = 'HYGothic-Extra'


plt.subplot(221)
sns.countplot(data=S_Laurent, x='days')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=S_Laurent, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=S_Laurent, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=S_Laurent, x='days', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Saint Laurent 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top4 : Louis Vuitton 데이터만 따로 보기

# %%
Louis_Vuitton = df.query('brandnm == "Louis Vuitton"')[:]
Louis_Vuitton
# Out:
#             brandnm                                   goodsnm      USER  \
# 10    Louis Vuitton  twist monogram patent shoulder bag black  a1140216
# 44    Louis Vuitton               monogram shoulder bag black   a164734
# 73    Louis Vuitton                alma epi pm tote bag black  a1141816
# 91    Louis Vuitton                     monogram clutch brown  a1141530
# 144   Louis Vuitton                 logo chain tote bag black  a1144704
# ...             ...                                       ...       ...
# 1325  Louis Vuitton         verni mini clutch chain bag brown  a1138484
# 1332  Louis Vuitton                     monogram clutch brown  a1148708
# 1384  Louis Vuitton       galliera gm Shoulder hobo Bag white  a1148221
# 1417  Louis Vuitton         Pochette trunk vertical black bag  a1148115
# 1426  Louis Vuitton                monogram two way bag brown  a1148075
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 10    2020-12-28  2021-01-15  7days       BA      Y  금요일       주중      1
# 44    2019-12-13  2021-01-13  4days       BA      Y  수요일       주중      1
# 73    2021-01-09  2021-01-09  7days       BA      Y  토요일       휴일      1
# 91    2021-01-07  2021-01-07  7days       BA      Y  목요일       주중      1
# 144   2021-01-27  2021-01-30  4days       BA      Y  토요일       휴일      1
# ...          ...         ...    ...      ...    ...  ...      ...    ...
# 1325  2020-12-20  2021-03-09  7days       BA      Y  화요일       주중      3
# 1332  2021-03-09  2021-03-09  4days       BA      Y  화요일       주중      3
# 1384  2021-03-04  2021-03-04  7days       BA      Y  목요일       주중      3
# 1417  2021-03-03  2021-03-03  4days       BA      Y  수요일       주중      3
# 1426  2021-03-03  2021-03-03  7days       BA      Y  수요일       주중      3
#
#       How_long
# 10          18
# 44         397
# 73           0
# 91           0
# 144          3
# ...        ...
# 1325        79
# 1332         0
# 1384         0
# 1417         0
# 1426         0
#
# [79 rows x 12 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.rcParams['font.family'] = 'HYGothic-Extra'


plt.subplot(221)
sns.countplot(data=Louis_Vuitton, x='days')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Louis_Vuitton, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Louis_Vuitton, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Louis_Vuitton, x='days', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Louis Vuitton 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top5 : Prada 데이터만 따로 보기

# %%
Prada = df.query('brandnm == "Prada"')[:]
Prada
# Out:
#      brandnm                                            goodsnm      USER  \
# 5      Prada                            ruffle detail long coat   a110231
# 12     Prada                        color fur detail coat black  a1137815
# 13     Prada                  zipper detail cape padding jumper  a1135135
# 15     Prada                                logo hobo bag black  a1143143
# 30     Prada                       quilted cross body bag black  a1142924
# 37     Prada                    single button modern coat black  a1142328
# 48     Prada                       collar point long coat multi   a189599
# 53     Prada  button check pattern wool singlebreasted-jacke...  a1120719
# 123    Prada                          padding two way bag black  a1141018
# 171    Prada                                logo hobo bag black  a1135097
# 176    Prada                   fur detail slim line single coat  a1144764
# 225    Prada                     gradation color padding jumper  a1105887
# 235    Prada                    gold logo crossbody bag hotpink   a168919
# 262    Prada               small logo classic two way bag black  a1144011
# 271    Prada                                saffiano lux M gray  a1143269
# 306    Prada                    button basic pattern coat black  a1143909
# 310    Prada                            striped strap cross bag  a1131731
# 327    Prada          pocket basic pattern padding-outer orange   a112000
# 348    Prada                   quilted chain shoulder bag black   a152462
# 370    Prada                           check pattern lined vest   a160435
# 375    Prada                         high neck robe jumper gray  a1112637
# 407    Prada                             saffiano mini bag blue  a1147227
# 413    Prada                     saffiano cross chain bag black  a1147510
# 414    Prada                  shirring detail two way bag black   a122219
# 443    Prada                saffiano leather mini crossbody bag  a1147237
# 470    Prada                      logo point suede bag burgundy  a1122302
# 551    Prada                      color strap shoulder bag navy  a1146831
# 611    Prada                  zipper detail cape padding jumper  a1146569
# 612    Prada                            striped strap cross bag  a1142928
# 631    Prada                     gradation color padding jumper  a1146458
# 634    Prada                     top handle corssbody bag black  a1135906
# 638    Prada                                pionniere bag brown  a1146306
# 668    Prada                           daino crossbody bag pink   a190885
# 674    Prada                  front button check pattern jacket   a145344
# 699    Prada                            tweed texture chain bag  a1145528
# 765    Prada                        daino crossbody bag black 2  a1145353
# 766    Prada                     saffiano cross chain bag black  a1145165
# 775    Prada                          round neck cardigan beige  a1145279
# 776    Prada                      color strap shoulder bag navy  a1145279
# 778    Prada                           check pattern lined vest  a1110447
# 785    Prada                        medium Nylon Backpack black  a1135783
# 803    Prada                        small logo bucket bag black  a1145039
# 825    Prada                    button basic pattern coat black  a1144978
# 855    Prada                  basic pattern padding-outer black  a1151457
# 964    Prada                          medium Nylon Backpack red  a1150796
# 1017   Prada                    new vit daino shopper bag black  a1145089
# 1100   Prada                            daino shoulder bag skin  a1149583
# 1129   Prada                            striped strap cross bag  a1149667
# 1224   Prada                      logo point suede bag burgundy  a1149465
# 1226   Prada                     saffiano cross chain bag black  a1146676
# 1252   Prada                             saffiano lux chain bag  a1148775
# 1270   Prada                     top handle corssbody bag black  a1148935
# 1289   Prada                saffiano leather mini crossbody bag  a1127412
# 1310   Prada                             quilted belt bag black  a1148428
# 1349   Prada                                logo hobo bag black  a1147639
# 1369   Prada                       unique pattern sweater multi   a175993
# 1427   Prada                      color strap shoulder bag navy  a1148019
# 1462   Prada                                saffiano lux M gray  a1146069
#
#         reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 5     2018-10-18  2021-01-15  7days        O      Y  금요일       주중      1
# 12    2020-12-18  2021-01-15  7days        O      Y  금요일       주중      1
# 13    2020-12-04  2021-01-15  7days        O      Y  금요일       주중      1
# 15    2021-01-15  2021-01-15  4days       BA      Y  금요일       주중      1
# 30    2021-01-14  2021-01-14  4days       BA      Y  목요일       주중      1
# 37    2021-01-11  2021-01-13  4days        O      Y  수요일       주중      1
# 48    2020-03-22  2021-01-13  7days        O      Y  수요일       주중      1
# 53    2020-09-21  2021-01-12  4days        O      Y  화요일       주중      1
# 123   2021-01-04  2021-01-04  4days       BA      Y  월요일       주중      1
# 171   2020-12-04  2021-01-28  4days       BA      Y  목요일       주중      1
# 176   2021-01-28  2021-01-28  4days        O      Y  목요일       주중      1
# 225   2020-06-24  2021-01-25  7days        O      Y  월요일       주중      1
# 235   2019-12-28  2021-01-25  7days       BA      Y  월요일       주중      1
# 262   2021-01-21  2021-01-22  4days       BA      Y  금요일       주중      1
# 271   2021-01-15  2021-01-21  4days       BA      Y  목요일       주중      1
# 306   2021-01-20  2021-01-20  4days        O      N  수요일       주중      1
# 310   2020-11-19  2021-01-20  7days       BA      Y  수요일       주중      1
# 327   2018-11-24  2021-01-19  4days        O      Y  화요일       주중      1
# 348   2019-10-30  2021-01-18  4days       BA      Y  월요일       주중      1
# 370   2019-12-03  2021-01-17  4days        T      Y  일요일       휴일      1
# 375   2020-08-16  2021-02-28  7days        O      Y  일요일       휴일      2
# 407   2021-02-22  2021-02-25  7days       BA      Y  목요일       주중      2
# 413   2021-02-25  2021-02-25  7days       BA      Y  목요일       주중      2
# 414   2019-05-08  2021-02-25  4days       BA      Y  목요일       주중      2
# 443   2021-02-23  2021-02-24  4days       BA      Y  수요일       주중      2
# 470   2020-10-03  2021-02-23  4days       BA      Y  화요일       주중      2
# 551   2021-02-18  2021-02-18  4days       BA      Y  목요일       주중      2
# 611   2021-02-16  2021-02-16  4days        O      Y  화요일       주중      2
# 612   2021-01-14  2021-02-16  7days       BA      Y  화요일       주중      2
# 631   2021-02-15  2021-02-15  7days        O      Y  월요일       주중      2
# 634   2020-12-08  2021-02-15  7days       BA      Y  월요일       주중      2
# 638   2021-02-13  2021-02-14  7days       BA      Y  일요일       휴일      2
# 668   2020-03-27  2021-02-09  4days       BA      Y  화요일       주중      2
# 674   2019-10-05  2021-02-09  4days        O      Y  화요일       주중      2
# 699   2021-02-05  2021-02-07  7days       BA      Y  일요일       휴일      2
# 765   2021-02-03  2021-02-04  4days       BA      Y  목요일       주중      2
# 766   2021-02-02  2021-02-04  7days       BA      Y  목요일       주중      2
# 775   2021-02-03  2021-02-03  4days        T      Y  수요일       주중      2
# 776   2021-02-03  2021-02-03  4days       BA      Y  수요일       주중      2
# 778   2020-08-05  2021-02-03  4days        T      Y  수요일       주중      2
# 785   2020-12-07  2021-02-03  4days       BA      Y  수요일       주중      2
# 803   2021-01-31  2021-02-02  7days       BA      Y  화요일       주중      2
# 825   2021-01-31  2021-02-01  7days        O      Y  월요일       주중      2
# 855   2021-03-30  2021-03-31  4days        O      Y  수요일       주중      3
# 964   2021-03-25  2021-03-25  7days       BA      Y  목요일       주중      3
# 1017  2021-02-01  2021-03-24  7days       BA      Y  수요일       주중      3
# 1100  2021-03-16  2021-03-19  4days       BA      N  금요일       주중      3
# 1129  2021-03-16  2021-03-18  4days       BA      Y  목요일       주중      3
# 1224  2021-03-15  2021-03-15  7days       BA      Y  월요일       주중      3
# 1226  2021-02-17  2021-03-15  4days       BA      Y  월요일       주중      3
# 1252  2021-03-09  2021-03-12  7days       BA      Y  금요일       주중      3
# 1270  2021-03-11  2021-03-11  7days       BA      Y  목요일       주중      3
# 1289  2020-10-28  2021-03-10  4days       BA      Y  수요일       주중      3
# 1310  2021-03-06  2021-03-09  4days       BA      N  화요일       주중      3
# 1349  2021-02-26  2021-03-07  4days       BA      Y  일요일       휴일      3
# 1369  2020-01-20  2021-03-05  7days        T      Y  금요일       주중      3
# 1427  2021-03-02  2021-03-03  7days       BA      Y  수요일       주중      3
# 1462  2021-02-11  2021-03-01  7days       BA      Y  공휴일       휴일      3
#
#       How_long
# 5          820
# 12          28
# 13          42
# 15           0
# 30           0
# 37           2
# 48         297
# 53         113
# 123          0
# 171         55
# 176          0
# 225        215
# 235        394
# 262          1
# 271          6
# 306          0
# 310         62
# 327        787
# 348        446
# 370        411
# 375        196
# 407          3
# 413          0
# 414        659
# 443          1
# 470        143
# 551          0
# 611          0
# 612         33
# 631          0
# 634         69
# 638          1
# 668        319
# 674        493
# 699          2
# 765          1
# 766          2
# 775          0
# 776          0
# 778        182
# 785         58
# 803          2
# 825          1
# 855          1
# 964          0
# 1017        51
# 1100         3
# 1129         2
# 1224         0
# 1226        26
# 1252         3
# 1270         0
# 1289       133
# 1310         3
# 1349         9
# 1369       410
# 1427         1
# 1462        18

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(221)
sns.countplot(data=Prada, x='days')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Prada, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Prada, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Prada, x='days', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Prada 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 2. 전체 아이템 중 선호도가 높은 순위 기준

# %%
# 개별 아이템별 선호도 상품 분석 

best_item = list(df.goodsnm.value_counts().head(11).index)
cnt = list(df.goodsnm.value_counts().head(11).values)

# %%
for i in range(len(best_item)):
    bname = df[df.goodsnm == best_item[i]]['brandnm'].unique()
    print(bname, ':', best_item[i], '주문수량', cnt[i])
# Out:
# ['Saint Laurent'] : chevron quilted cross bag black 주문수량 23
# ['Chanel'] : classic clutch black 주문수량 12
# ['Chanel'] : boy chanel clutch black 주문수량 11
# ['Gucci'] : padlock GG canvas shoulder bag 주문수량 9
# ['Saint Laurent'] : mini sunset chain bag black 주문수량 8
# ['Louis Vuitton'] : epi tote bag black 주문수량 8
# ['Gucci'] : dionysus shoulder bag beige 주문수량 8
# ['Saint Laurent' 'Chanel'] : quilted shoulder bag black 주문수량 7
# ['Gucci'] : dionysus cross bag beige 주문수량 7
# ['Louis Vuitton'] : monogram clutch brown 주문수량 7
# ['Gucci'] : flap cross bag black 주문수량 7

# %%
# 월별/요일별/ 개별 아이템 사진첨부

# %% [markdown]
# # 상위 아이템 분석

# %% [markdown]
# - ['Saint Laurent'] : chevron quilted cross bag black 주문수량 23
# - ['Chanel'] : classic clutch black 주문수량 12
# - ['Chanel'] : boy chanel clutch black 주문수량 11

# %%
cross_bag = df.query('goodsnm == "chevron quilted cross bag black"')
cluth_black = df.query('goodsnm == "classic clutch black"')
chanel_cluth = df.query('goodsnm == "boy chanel clutch black"')

# %% [markdown]
# ## 월별 count

# %%
plt.figure(figsize=(20,7))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(131)
sns.countplot(data=cross_bag, x='month')
plt.title('Saint Laurent - chevron quilted cross bag black 월별 count')

plt.subplot(132)
sns.countplot(data=cluth_black, x='month')
plt.title('Chanel - classic cluth black 월별 count')

plt.subplot(133)
sns.countplot(data=chanel_cluth, x='month')
plt.title('Chanel - boy chanel cluth black 월별 count')

plt.suptitle('상위 제품 3개 월별 count',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# - 생로랑은 1 = 2 < 3월
# - 샤넬은 1월달 데이터가 없음. 두 제품 모두 2 < 3
#     - 그렇다면 chanel 제품들은 2월에 업데이트 된 상품이 아닐까? 라는 추측을 해봄

# %% [markdown]
# ## 요일별 count

# %%
#요일별 아이템 분석

plt.figure(figsize=(20,7))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(131)
sns.countplot(data=cross_bag, x='days')
plt.title('Saint Laurent - chevron quilted cross bag black 요일별 count')

plt.subplot(132)
sns.countplot(data=cluth_black, x='days')
plt.title('Chanel - classic cluth black 요일별 count')

plt.subplot(133)
sns.countplot(data=chanel_cluth, x='days')
plt.title('Chanel - boy chanel cluth black 요일별 count')

plt.suptitle('상위 제품 3개 요일별 count',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 주중/휴일별 아이템 분석

# %%
plt.figure(figsize=(20,8))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(131)
sns.countplot(data=cross_bag, x='day_type')
plt.title('Saint Laurent - chevron quilted cross bag black 주중/주말별 count')

plt.subplot(132)
sns.countplot(data=cluth_black, x='day_type')
plt.title('Chanel - classic cluth black 주중/주말별 count')

plt.subplot(133)
sns.countplot(data=chanel_cluth, x='day_type')
plt.title('Chanel - boy chanel cluth black 주중/주말별 count')

plt.suptitle('상위 제품 3개 주중/휴일별 count',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 가입 후 기간별 아이템 분석

# %%
plt.figure(figsize=(20,8))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(131)
sns.countplot(data=cross_bag, x='How_long')
plt.title('Saint Laurent - chevron quilted cross bag black 가입후 기간별 count')

plt.subplot(132)
sns.countplot(data=cluth_black, x='How_long')
plt.title('Chanel - classic cluth black 가입후 기간별 count')

plt.subplot(133)
sns.countplot(data=chanel_cluth, x='How_long')
plt.title('Chanel - boy chanel cluth black 가입후 기간별 count')

plt.suptitle('상위 제품 3개 가입 후 기간별 count',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# - 대부분이 가입 당일 혹은 1일 이내에 빌림

# %%
print(cluth_black[cluth_black['How_long'] > 1]['order_date'], '\n')
print(cluth_black[cluth_black['How_long'] > 1]['order_date'].min())
# Out:
# 464     2021-02-24
# 649     2021-02-13
# 741     2021-02-04
# 839     2021-03-31
# 973     2021-03-25
# 978     2021-03-24
# 1309    2021-03-09
# 1333    2021-03-09
# Name: order_date, dtype: object
#
# 2021-02-04

# %%
print(chanel_cluth[chanel_cluth['How_long'] > 1]['order_date'], '\n')
print(chanel_cluth[chanel_cluth['How_long'] > 1]['order_date'].min())
# Out:
# 750     2021-02-04
# 1192    2021-03-16
# Name: order_date, dtype: object
#
# 2021-02-04

# %% [markdown]
# ### idea?

# %% [markdown]
# - 아까 위에서 chanel 제품들은 2월에 들어온 상품이 아닐까? 란 가정을 세웠는데,<br> 가입한 지 꽤 된 유저들의 구매일자를 확인해보니 모두 2,3월임 이 중 가장 빠른 결제일이 **2월 4일**
# - 샤넬의 두 번째 제품도 마찬가지임. 가장 빠른 결제일이 **2월 4일**
# - **상위 제품 2,3위인 샤넬의 제품은 2월에 업데이트 된 것으로 판단**
#     - 신상에 대한 욕구 有?
#         - 이게 진짜 시즌 신상인지, 아니면 클로젯 셰어 내에서의 신상일지 판단 확인 필요
#         - 클로젯 셰어에서 검색한 결과, 동일 제품인데 new 라벨이 붙어있는 제품 존재. **클로젯 셰어 내부에서의 신상(재고가 추가됨)으로 판단**
#
# - 상위 3개 제품의 디자인은 모두 **베이직한 디자인**임. 게다가 모두 **검정색**
#     - *클로젯 셰어 인스타그램에 베스트 셀러 bags들을 모아놨는데 ..... 음.. 어떻게 연결지을 수 있을까요*
#     - 클로젯 셰어 인스타그램 주소 : https://www.instagram.com/closetshare_kr/
#         - 게시글 보려면 로그인 필수

# %% [markdown]
# ## 일회권 별 count

# %%
#요일별 아이템 분석

plt.figure(figsize=(20,8))
plt.rcParams['font.family'] = 'HYGothic-Extra'

plt.subplot(131)
sns.countplot(data=cross_bag, x='p_type')
plt.title('Saint Laurent - chevron quilted cross bag black 일회권별 count')

plt.subplot(132)
sns.countplot(data=cluth_black, x='p_type')
plt.title('Chanel - classic cluth black 일회권별 count')

plt.subplot(133)
sns.countplot(data=chanel_cluth, x='p_type')
plt.title('Chanel - boy chanel cluth black 일회권별 count')

plt.suptitle('상위 제품 3개 일회권별 count',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# - 생로랑과 샤넬 classicd cluth black 제품은 4days가 많고, boy chanel cluth black은 7days가 많음
#     - 같은 브랜드의 아이템인데 왜 차이가 있을까?
#         - chanel classic clutch black : 39000/49000원 多 (15개 존재)
#         - boy chanel cluth black : 49000/59000 (1개 존재)
#            - 가격은 비슷한데? 재고 수의 차이 때문일까?
